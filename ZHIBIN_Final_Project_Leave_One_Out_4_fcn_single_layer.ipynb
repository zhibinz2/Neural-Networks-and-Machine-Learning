# %% [markdown]
# <a href="https://colab.research.google.com/github/zhibinz2/Neural-Networks-and-Machine-Learning/blob/master/ZHIBIN_Final_Project_Leave_One_Out_4_fcn_single_layer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
# !wget https://github.com/zhibinz2/Neural-Networks-and-Machine-Learning/raw/master/AwakeSamples.npy
AwakeSamples=np.load('AwakeSamples.npy')
# !wget https://github.com/zhibinz2/Neural-Networks-and-Machine-Learning/raw/master/SedatedSamples.npy
SedatedSamples=np.load('SedatedSamples.npy')

import tqdm

import torch
from torch import optim
from torch import nn


import torchvision
from torchvision import datasets, transforms
import torchvision.transforms as transforms
from torchvision import models, transforms
from torch.autograd import Variable

import pandas as pd
from PIL import Image
import requests
import io
import random, time, sys
from collections import namedtuple

import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
# Out:
# --2020-12-09 06:40:20--  https://github.com/zhibinz2/Neural-Networks-and-Machine-Learning/raw/master/AwakeSamples.npy
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/zhibinz2/Neural-Networks-and-Machine-Learning/master/AwakeSamples.npy [following]
# --2020-12-09 06:40:21--  https://raw.githubusercontent.com/zhibinz2/Neural-Networks-and-Machine-Learning/master/AwakeSamples.npy
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13249728 (13M) [application/octet-stream]
# Saving to: ‘AwakeSamples.npy’
#
# AwakeSamples.npy    100%[===================>]  12.64M  60.4MB/s    in 0.2s
#
# 2020-12-09 06:40:21 (60.4 MB/s) - ‘AwakeSamples.npy’ saved [13249728/13249728]
#
# --2020-12-09 06:40:21--  https://github.com/zhibinz2/Neural-Networks-and-Machine-Learning/raw/master/SedatedSamples.npy
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/zhibinz2/Neural-Networks-and-Machine-Learning/master/SedatedSamples.npy [following]
# --2020-12-09 06:40:22--  https://raw.githubusercontent.com/zhibinz2/Neural-Networks-and-Machine-Learning/master/SedatedSamples.npy
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13249728 (13M) [application/octet-stream]
# Saving to: ‘SedatedSamples.npy’
#
# SedatedSamples.npy  100%[===================>]  12.64M  71.7MB/s    in 0.2s
#
# 2020-12-09 06:40:22 (71.7 MB/s) - ‘SedatedSamples.npy’ saved [13249728/13249728]

# %%
# Conbine two categories of samples into data
data=np.concatenate((AwakeSamples,SedatedSamples),axis=0)

# %%
# Add one dimension, needed for both single layer FCN and convolutional network
data=np.expand_dims(data, axis=1)

# %%
# only for single layer FCN
import numpy.matlib
A=numpy.matlib.repmat(np.array([1, 0]),200,1)
B=numpy.matlib.repmat(np.array([0, 1]),200,1)
targets=np.concatenate((A,B),axis=0)

# %%
# leave one out
from sklearn.model_selection import LeaveOneOut
loo = LeaveOneOut()
loo.get_n_splits(data)
# Out:
# 400

# %%
from torch.utils.data import Dataset
class MyTrainingDataset(Dataset):
    def __init__(self, root, transform=None, target_transform=None):
        self.root=root
        self.transform=transform
        self.target_transform=target_transform
        self.data=np.load(self.root[0])
        self.targets=np.load(self.root[1])
        
    def __len__(self):
        return len(self.data)
 
    def __getitem__(self, idx):
        sample=self.data[idx] 
        target=self.targets[idx]
        
        if self.transform:
            sample=self.transform(sample)
        if self.target_transform:
            target=self.target_transform(target)
            
        return sample, target

# %%
net = torch.nn.Sequential(torch.nn.Linear(8281, 100),torch.nn.Sigmoid(),torch.nn.Linear(100,2),
                                  torch.nn.Sigmoid())

# %%
mse_loss = torch.nn.MSELoss()
opt = torch.optim.Adam(net.parameters(), lr=1e-3)

# %%
def train_step(x, t, net, opt_fn, loss_fn):
    y = net(x)
    loss = loss_fn(y, t)
    loss.backward()
    opt_fn.step()
    opt_fn.zero_grad()
    return loss

# %%
batch=100

# %%
acc_hist_train = []
acc_hist_test = []

for train_index, test_index in loo.split(data):
  #print("TRAIN:", train_index, "TEST:", test_index)
  train_data, test_data = data[train_index], data[test_index]
  train_targets, test_targets = targets[train_index], targets[test_index]
  #print(train_data, test_data, train_targets, test_targets)

  np.save('train_data.npy',train_data)
  np.save('train_targets.npy',train_targets)
  train_set=MyTrainingDataset(root=['train_data.npy', 'train_targets.npy'])

  np.save('test_data.npy',test_data)
  np.save('test_targets.npy',test_targets)
  test_set=MyTrainingDataset(root=['test_data.npy', 'test_targets.npy'])

  train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch, shuffle=True)
  test_loader = torch.utils.data.DataLoader(test_set, batch_size=batch, shuffle=False)

  # 4_fcn_single_layer
  x,t = next(iter(train_loader))
  train_step(x.float().view(-1,8281), t.float(), net, opt, mse_loss)

  # Make prediction
  for x,t in iter(train_loader):
    y = net(x.float().view(-1,8281))

  # Calculate accuracy
  torch.mean((t.argmax(1) == y.argmax(1)).float())

  # Train the network over multiple epochs
  for epoch in range(5):
    acc_batch = []
    for x,t in iter(train_loader):
      loss_ = train_step(x.float().view(-1,8281), t.float(), net, opt, mse_loss)
      y = net(x.float().view(-1,8281))
      acc_batch.append(torch.mean((t.argmax(1) == y.argmax(1)).float()))
    acc_hist_train.append(torch.mean(torch.FloatTensor(acc_batch)))
    print(loss_)

    acc_batch = []
    for x,t in iter(test_loader):
      y = net(x.float().view(-1,8281))
      acc_batch.append(torch.mean((t.argmax(1) == y.argmax(1)).float()))
    acc_hist_test.append(torch.mean(torch.FloatTensor(acc_batch)))

  acc_hist_train
  acc_hist_test
# Out:
# tensor(9.8315e-12, grad_fn=<MseLossBackward>)
# tensor(9.6457e-12, grad_fn=<MseLossBackward>)
# tensor(1.3554e-11, grad_fn=<MseLossBackward>)
# tensor(9.6485e-12, grad_fn=<MseLossBackward>)
# tensor(8.9082e-12, grad_fn=<MseLossBackward>)
# tensor(1.3531e-11, grad_fn=<MseLossBackward>)
# tensor(5.8102e-12, grad_fn=<MseLossBackward>)
# tensor(1.0813e-11, grad_fn=<MseLossBackward>)
# tensor(9.3605e-12, grad_fn=<MseLossBackward>)
# tensor(7.7895e-12, grad_fn=<MseLossBackward>)
# tensor(8.3246e-12, grad_fn=<MseLossBackward>)
# tensor(1.0461e-11, grad_fn=<MseLossBackward>)
# tensor(1.2691e-11, grad_fn=<MseLossBackward>)
# tensor(7.0221e-12, grad_fn=<MseLossBackward>)
# tensor(1.2080e-11, grad_fn=<MseLossBackward>)
# tensor(1.1009e-11, grad_fn=<MseLossBackward>)
# tensor(9.3435e-12, grad_fn=<MseLossBackward>)
# tensor(9.5412e-12, grad_fn=<MseLossBackward>)
# tensor(6.9300e-12, grad_fn=<MseLossBackward>)
# tensor(1.0587e-11, grad_fn=<MseLossBackward>)
# tensor(1.1554e-11, grad_fn=<MseLossBackward>)
# tensor(9.5813e-12, grad_fn=<MseLossBackward>)
# tensor(9.0863e-12, grad_fn=<MseLossBackward>)
# tensor(1.7646e-11, grad_fn=<MseLossBackward>)
# tensor(1.0389e-11, grad_fn=<MseLossBackward>)
# tensor(1.0471e-11, grad_fn=<MseLossBackward>)
# tensor(7.1143e-12, grad_fn=<MseLossBackward>)
# tensor(8.5164e-12, grad_fn=<MseLossBackward>)
# tensor(9.6639e-12, grad_fn=<MseLossBackward>)
# tensor(1.2951e-11, grad_fn=<MseLossBackward>)
# tensor(9.4011e-12, grad_fn=<MseLossBackward>)
# tensor(9.2861e-12, grad_fn=<MseLossBackward>)
# tensor(1.1326e-11, grad_fn=<MseLossBackward>)
# tensor(1.3803e-11, grad_fn=<MseLossBackward>)
# tensor(1.2038e-11, grad_fn=<MseLossBackward>)
# tensor(1.2557e-11, grad_fn=<MseLossBackward>)
# tensor(1.5975e-11, grad_fn=<MseLossBackward>)
# tensor(8.5920e-12, grad_fn=<MseLossBackward>)
# tensor(8.3333e-12, grad_fn=<MseLossBackward>)
# tensor(1.3776e-11, grad_fn=<MseLossBackward>)
# tensor(1.1610e-11, grad_fn=<MseLossBackward>)
# tensor(8.5393e-12, grad_fn=<MseLossBackward>)
# tensor(9.2319e-12, grad_fn=<MseLossBackward>)
# tensor(9.1655e-12, grad_fn=<MseLossBackward>)
# tensor(1.1061e-11, grad_fn=<MseLossBackward>)
# tensor(5.3268e-12, grad_fn=<MseLossBackward>)
# tensor(8.4721e-12, grad_fn=<MseLossBackward>)
# tensor(1.2128e-11, grad_fn=<MseLossBackward>)
# tensor(1.1076e-11, grad_fn=<MseLossBackward>)
# tensor(1.3820e-11, grad_fn=<MseLossBackward>)
# tensor(1.0945e-11, grad_fn=<MseLossBackward>)
# tensor(1.4560e-11, grad_fn=<MseLossBackward>)
# tensor(1.0149e-11, grad_fn=<MseLossBackward>)
# tensor(6.6309e-12, grad_fn=<MseLossBackward>)
# tensor(1.0797e-11, grad_fn=<MseLossBackward>)
# tensor(7.9518e-12, grad_fn=<MseLossBackward>)
# tensor(1.3709e-11, grad_fn=<MseLossBackward>)
# tensor(9.2035e-12, grad_fn=<MseLossBackward>)
# tensor(7.5165e-12, grad_fn=<MseLossBackward>)
# tensor(1.1578e-11, grad_fn=<MseLossBackward>)
# tensor(9.6343e-12, grad_fn=<MseLossBackward>)
# tensor(7.0974e-12, grad_fn=<MseLossBackward>)
# tensor(1.0437e-11, grad_fn=<MseLossBackward>)
# tensor(6.7561e-12, grad_fn=<MseLossBackward>)
# tensor(5.7247e-12, grad_fn=<MseLossBackward>)
# tensor(6.2154e-12, grad_fn=<MseLossBackward>)
# tensor(1.0507e-11, grad_fn=<MseLossBackward>)
# tensor(1.1645e-11, grad_fn=<MseLossBackward>)
# tensor(9.9007e-12, grad_fn=<MseLossBackward>)
# tensor(8.1251e-12, grad_fn=<MseLossBackward>)
# tensor(7.9886e-12, grad_fn=<MseLossBackward>)
# tensor(1.2670e-11, grad_fn=<MseLossBackward>)
# tensor(9.6659e-12, grad_fn=<MseLossBackward>)
# tensor(8.1351e-12, grad_fn=<MseLossBackward>)
# tensor(1.3375e-11, grad_fn=<MseLossBackward>)
# tensor(8.5569e-12, grad_fn=<MseLossBackward>)
# tensor(7.6664e-12, grad_fn=<MseLossBackward>)
# tensor(1.3194e-11, grad_fn=<MseLossBackward>)
# tensor(1.1359e-11, grad_fn=<MseLossBackward>)
# tensor(1.2291e-11, grad_fn=<MseLossBackward>)
# tensor(1.1064e-11, grad_fn=<MseLossBackward>)
# tensor(1.0798e-11, grad_fn=<MseLossBackward>)
# tensor(1.1452e-11, grad_fn=<MseLossBackward>)
# tensor(1.0246e-11, grad_fn=<MseLossBackward>)
# tensor(1.2056e-11, grad_fn=<MseLossBackward>)
# tensor(8.4888e-12, grad_fn=<MseLossBackward>)
# tensor(7.5635e-12, grad_fn=<MseLossBackward>)
# tensor(8.0107e-12, grad_fn=<MseLossBackward>)
# tensor(8.7738e-12, grad_fn=<MseLossBackward>)
# tensor(1.1835e-11, grad_fn=<MseLossBackward>)
# tensor(1.6913e-11, grad_fn=<MseLossBackward>)
# tensor(1.2670e-11, grad_fn=<MseLossBackward>)
# tensor(9.2399e-12, grad_fn=<MseLossBackward>)
# tensor(1.4120e-11, grad_fn=<MseLossBackward>)
# tensor(1.3717e-11, grad_fn=<MseLossBackward>)
# tensor(4.8664e-12, grad_fn=<MseLossBackward>)
# tensor(9.9116e-12, grad_fn=<MseLossBackward>)
# tensor(9.6384e-12, grad_fn=<MseLossBackward>)
# tensor(7.7173e-12, grad_fn=<MseLossBackward>)
# tensor(1.1402e-11, grad_fn=<MseLossBackward>)
# tensor(1.2434e-11, grad_fn=<MseLossBackward>)
# tensor(8.0356e-12, grad_fn=<MseLossBackward>)
# tensor(1.5326e-11, grad_fn=<MseLossBackward>)
# tensor(7.8633e-12, grad_fn=<MseLossBackward>)
# tensor(6.0306e-12, grad_fn=<MseLossBackward>)
# tensor(1.4065e-11, grad_fn=<MseLossBackward>)
# tensor(8.7348e-12, grad_fn=<MseLossBackward>)
# tensor(7.0051e-12, grad_fn=<MseLossBackward>)
# tensor(8.9728e-12, grad_fn=<MseLossBackward>)
# tensor(8.9648e-12, grad_fn=<MseLossBackward>)
# tensor(1.1447e-11, grad_fn=<MseLossBackward>)
# tensor(1.2207e-11, grad_fn=<MseLossBackward>)
# tensor(7.1457e-12, grad_fn=<MseLossBackward>)
# tensor(9.8222e-12, grad_fn=<MseLossBackward>)
# tensor(6.5582e-12, grad_fn=<MseLossBackward>)
# tensor(6.8685e-12, grad_fn=<MseLossBackward>)
# tensor(9.0211e-12, grad_fn=<MseLossBackward>)
# tensor(8.5031e-12, grad_fn=<MseLossBackward>)
# tensor(1.0753e-11, grad_fn=<MseLossBackward>)
# tensor(9.8881e-12, grad_fn=<MseLossBackward>)
# tensor(1.2223e-11, grad_fn=<MseLossBackward>)
# tensor(1.0997e-11, grad_fn=<MseLossBackward>)
# tensor(7.0705e-12, grad_fn=<MseLossBackward>)
# tensor(5.8828e-12, grad_fn=<MseLossBackward>)
# tensor(9.4937e-12, grad_fn=<MseLossBackward>)
# tensor(9.3506e-12, grad_fn=<MseLossBackward>)
# tensor(1.1767e-11, grad_fn=<MseLossBackward>)
# tensor(1.2605e-11, grad_fn=<MseLossBackward>)
# tensor(5.1827e-12, grad_fn=<MseLossBackward>)
# tensor(1.1799e-11, grad_fn=<MseLossBackward>)
# tensor(7.7470e-12, grad_fn=<MseLossBackward>)
# tensor(1.4439e-11, grad_fn=<MseLossBackward>)
# tensor(8.0323e-12, grad_fn=<MseLossBackward>)
# tensor(9.3692e-12, grad_fn=<MseLossBackward>)
# tensor(5.3386e-12, grad_fn=<MseLossBackward>)
# tensor(7.0934e-12, grad_fn=<MseLossBackward>)
# tensor(1.2864e-11, grad_fn=<MseLossBackward>)
# tensor(8.8339e-12, grad_fn=<MseLossBackward>)
# tensor(1.1268e-11, grad_fn=<MseLossBackward>)
# tensor(9.7716e-12, grad_fn=<MseLossBackward>)
# tensor(1.0031e-11, grad_fn=<MseLossBackward>)
# tensor(1.1448e-11, grad_fn=<MseLossBackward>)
# tensor(8.8631e-12, grad_fn=<MseLossBackward>)
# tensor(1.0351e-11, grad_fn=<MseLossBackward>)
# tensor(6.7297e-12, grad_fn=<MseLossBackward>)
# tensor(1.1592e-11, grad_fn=<MseLossBackward>)
# tensor(1.6904e-11, grad_fn=<MseLossBackward>)
# tensor(1.6254e-11, grad_fn=<MseLossBackward>)
# tensor(7.4180e-12, grad_fn=<MseLossBackward>)
# tensor(1.5529e-11, grad_fn=<MseLossBackward>)
# tensor(1.1672e-11, grad_fn=<MseLossBackward>)
# tensor(5.5743e-12, grad_fn=<MseLossBackward>)
# tensor(7.8499e-12, grad_fn=<MseLossBackward>)
# tensor(7.8985e-12, grad_fn=<MseLossBackward>)
# tensor(8.7584e-12, grad_fn=<MseLossBackward>)
# tensor(8.7100e-12, grad_fn=<MseLossBackward>)
# tensor(1.0582e-11, grad_fn=<MseLossBackward>)
# tensor(1.3924e-11, grad_fn=<MseLossBackward>)
# tensor(1.1144e-11, grad_fn=<MseLossBackward>)
# tensor(8.7005e-12, grad_fn=<MseLossBackward>)
# tensor(1.2452e-11, grad_fn=<MseLossBackward>)
# tensor(7.4037e-12, grad_fn=<MseLossBackward>)
# tensor(9.4551e-12, grad_fn=<MseLossBackward>)
# tensor(9.9644e-12, grad_fn=<MseLossBackward>)
# tensor(7.2594e-12, grad_fn=<MseLossBackward>)
# tensor(9.9405e-12, grad_fn=<MseLossBackward>)
# tensor(9.2697e-12, grad_fn=<MseLossBackward>)
# tensor(1.2296e-11, grad_fn=<MseLossBackward>)
# tensor(1.0335e-11, grad_fn=<MseLossBackward>)
# tensor(1.2183e-11, grad_fn=<MseLossBackward>)
# tensor(1.2992e-11, grad_fn=<MseLossBackward>)
# tensor(1.0298e-11, grad_fn=<MseLossBackward>)
# tensor(1.4360e-11, grad_fn=<MseLossBackward>)
# tensor(1.0837e-11, grad_fn=<MseLossBackward>)
# tensor(7.4863e-12, grad_fn=<MseLossBackward>)
# tensor(1.1098e-11, grad_fn=<MseLossBackward>)
# tensor(1.2631e-11, grad_fn=<MseLossBackward>)
# tensor(6.4773e-12, grad_fn=<MseLossBackward>)
# tensor(7.6793e-12, grad_fn=<MseLossBackward>)
# tensor(7.7191e-12, grad_fn=<MseLossBackward>)
# tensor(8.5877e-12, grad_fn=<MseLossBackward>)
# tensor(1.1202e-11, grad_fn=<MseLossBackward>)
# tensor(9.2324e-12, grad_fn=<MseLossBackward>)
# tensor(7.9220e-12, grad_fn=<MseLossBackward>)
# tensor(1.0870e-11, grad_fn=<MseLossBackward>)
# tensor(4.9763e-12, grad_fn=<MseLossBackward>)
# tensor(1.0469e-11, grad_fn=<MseLossBackward>)
# tensor(8.1078e-12, grad_fn=<MseLossBackward>)
# tensor(1.2663e-11, grad_fn=<MseLossBackward>)
# tensor(7.2839e-12, grad_fn=<MseLossBackward>)
# tensor(1.0691e-11, grad_fn=<MseLossBackward>)
# tensor(1.1686e-11, grad_fn=<MseLossBackward>)
# tensor(1.0514e-11, grad_fn=<MseLossBackward>)
# tensor(8.1384e-12, grad_fn=<MseLossBackward>)
# tensor(9.7637e-12, grad_fn=<MseLossBackward>)
# tensor(1.0231e-11, grad_fn=<MseLossBackward>)
# tensor(1.1227e-11, grad_fn=<MseLossBackward>)
# tensor(7.5932e-12, grad_fn=<MseLossBackward>)
# tensor(8.7952e-12, grad_fn=<MseLossBackward>)
# tensor(6.5634e-12, grad_fn=<MseLossBackward>)
# tensor(1.4411e-11, grad_fn=<MseLossBackward>)
# tensor(7.8452e-12, grad_fn=<MseLossBackward>)
# tensor(8.2361e-12, grad_fn=<MseLossBackward>)
# tensor(1.1614e-11, grad_fn=<MseLossBackward>)
# tensor(7.6302e-12, grad_fn=<MseLossBackward>)
# tensor(1.0636e-11, grad_fn=<MseLossBackward>)
# tensor(8.1121e-12, grad_fn=<MseLossBackward>)
# tensor(1.0033e-11, grad_fn=<MseLossBackward>)
# tensor(1.5481e-11, grad_fn=<MseLossBackward>)
# tensor(8.7560e-12, grad_fn=<MseLossBackward>)
# tensor(1.4560e-11, grad_fn=<MseLossBackward>)
# tensor(7.8137e-12, grad_fn=<MseLossBackward>)
# tensor(7.8081e-12, grad_fn=<MseLossBackward>)
# tensor(8.6260e-12, grad_fn=<MseLossBackward>)
# tensor(8.4210e-12, grad_fn=<MseLossBackward>)
# tensor(1.1211e-11, grad_fn=<MseLossBackward>)
# tensor(1.5084e-11, grad_fn=<MseLossBackward>)
# tensor(1.1115e-11, grad_fn=<MseLossBackward>)
# tensor(1.0825e-11, grad_fn=<MseLossBackward>)
# tensor(7.1212e-12, grad_fn=<MseLossBackward>)
# tensor(1.0934e-11, grad_fn=<MseLossBackward>)
# tensor(9.2698e-12, grad_fn=<MseLossBackward>)
# tensor(6.0618e-12, grad_fn=<MseLossBackward>)
# tensor(1.1820e-11, grad_fn=<MseLossBackward>)
# tensor(1.1919e-11, grad_fn=<MseLossBackward>)
# tensor(1.5754e-11, grad_fn=<MseLossBackward>)
# tensor(1.1879e-11, grad_fn=<MseLossBackward>)
# tensor(1.4891e-11, grad_fn=<MseLossBackward>)
# tensor(1.4619e-11, grad_fn=<MseLossBackward>)
# tensor(1.1216e-11, grad_fn=<MseLossBackward>)
# tensor(1.1779e-11, grad_fn=<MseLossBackward>)
# tensor(6.7666e-12, grad_fn=<MseLossBackward>)
# tensor(1.2892e-11, grad_fn=<MseLossBackward>)
# tensor(8.2764e-12, grad_fn=<MseLossBackward>)
# tensor(8.6126e-12, grad_fn=<MseLossBackward>)
# tensor(1.3519e-11, grad_fn=<MseLossBackward>)
# tensor(1.0592e-11, grad_fn=<MseLossBackward>)
# tensor(7.1177e-12, grad_fn=<MseLossBackward>)
# tensor(1.2915e-11, grad_fn=<MseLossBackward>)
# tensor(1.2233e-11, grad_fn=<MseLossBackward>)
# tensor(1.0644e-11, grad_fn=<MseLossBackward>)
# tensor(8.7367e-12, grad_fn=<MseLossBackward>)
# tensor(1.2277e-11, grad_fn=<MseLossBackward>)
# tensor(7.5882e-12, grad_fn=<MseLossBackward>)
# tensor(1.2031e-11, grad_fn=<MseLossBackward>)
# tensor(8.1295e-12, grad_fn=<MseLossBackward>)
# tensor(1.0350e-11, grad_fn=<MseLossBackward>)
# tensor(8.2194e-12, grad_fn=<MseLossBackward>)
# tensor(1.3214e-11, grad_fn=<MseLossBackward>)
# tensor(9.4212e-12, grad_fn=<MseLossBackward>)
# tensor(9.1867e-12, grad_fn=<MseLossBackward>)
# tensor(8.1808e-12, grad_fn=<MseLossBackward>)
# tensor(7.7426e-12, grad_fn=<MseLossBackward>)
# tensor(1.0322e-11, grad_fn=<MseLossBackward>)
# tensor(1.4575e-11, grad_fn=<MseLossBackward>)
# tensor(6.8658e-12, grad_fn=<MseLossBackward>)
# tensor(8.1354e-12, grad_fn=<MseLossBackward>)
# tensor(9.1052e-12, grad_fn=<MseLossBackward>)
# tensor(7.7175e-12, grad_fn=<MseLossBackward>)
# tensor(8.0962e-12, grad_fn=<MseLossBackward>)
# tensor(8.5716e-12, grad_fn=<MseLossBackward>)
# tensor(1.0999e-11, grad_fn=<MseLossBackward>)
# tensor(6.2726e-12, grad_fn=<MseLossBackward>)
# tensor(7.1696e-12, grad_fn=<MseLossBackward>)
# tensor(6.5973e-12, grad_fn=<MseLossBackward>)
# tensor(7.4302e-12, grad_fn=<MseLossBackward>)
# tensor(9.0364e-12, grad_fn=<MseLossBackward>)
# tensor(1.2719e-11, grad_fn=<MseLossBackward>)
# tensor(1.0696e-11, grad_fn=<MseLossBackward>)
# tensor(9.7602e-12, grad_fn=<MseLossBackward>)
# tensor(1.0656e-11, grad_fn=<MseLossBackward>)
# tensor(8.0136e-12, grad_fn=<MseLossBackward>)
# tensor(9.9775e-12, grad_fn=<MseLossBackward>)
# tensor(1.4149e-11, grad_fn=<MseLossBackward>)
# tensor(1.2377e-11, grad_fn=<MseLossBackward>)
# tensor(7.7887e-12, grad_fn=<MseLossBackward>)
# tensor(7.3521e-12, grad_fn=<MseLossBackward>)
# tensor(1.4663e-11, grad_fn=<MseLossBackward>)
# tensor(7.5562e-12, grad_fn=<MseLossBackward>)
# tensor(1.2150e-11, grad_fn=<MseLossBackward>)
# tensor(9.3377e-12, grad_fn=<MseLossBackward>)
# tensor(1.0542e-11, grad_fn=<MseLossBackward>)
# tensor(1.0304e-11, grad_fn=<MseLossBackward>)
# tensor(7.4160e-12, grad_fn=<MseLossBackward>)
# tensor(7.0277e-12, grad_fn=<MseLossBackward>)
# tensor(9.4426e-12, grad_fn=<MseLossBackward>)
# tensor(6.6734e-12, grad_fn=<MseLossBackward>)
# tensor(1.0001e-11, grad_fn=<MseLossBackward>)
# tensor(1.1867e-11, grad_fn=<MseLossBackward>)
# tensor(1.5008e-11, grad_fn=<MseLossBackward>)
# tensor(1.0819e-11, grad_fn=<MseLossBackward>)
# tensor(1.0012e-11, grad_fn=<MseLossBackward>)
# tensor(7.2689e-12, grad_fn=<MseLossBackward>)
# tensor(1.1747e-11, grad_fn=<MseLossBackward>)
# tensor(8.0134e-12, grad_fn=<MseLossBackward>)
# tensor(6.2023e-12, grad_fn=<MseLossBackward>)
# tensor(9.9970e-12, grad_fn=<MseLossBackward>)
# tensor(1.1475e-11, grad_fn=<MseLossBackward>)
# tensor(1.2202e-11, grad_fn=<MseLossBackward>)
# tensor(9.0160e-12, grad_fn=<MseLossBackward>)
# tensor(1.2229e-11, grad_fn=<MseLossBackward>)
# tensor(4.8910e-12, grad_fn=<MseLossBackward>)
# tensor(6.1305e-12, grad_fn=<MseLossBackward>)
# tensor(9.7129e-12, grad_fn=<MseLossBackward>)
# tensor(8.8574e-12, grad_fn=<MseLossBackward>)
# tensor(1.2305e-11, grad_fn=<MseLossBackward>)
# tensor(7.8873e-12, grad_fn=<MseLossBackward>)
# tensor(1.2653e-11, grad_fn=<MseLossBackward>)
# tensor(1.3737e-11, grad_fn=<MseLossBackward>)
# tensor(1.1150e-11, grad_fn=<MseLossBackward>)
# tensor(6.7680e-12, grad_fn=<MseLossBackward>)
# tensor(6.4303e-12, grad_fn=<MseLossBackward>)
# tensor(7.2549e-12, grad_fn=<MseLossBackward>)
# tensor(1.2712e-11, grad_fn=<MseLossBackward>)
# tensor(1.6149e-11, grad_fn=<MseLossBackward>)
# tensor(8.3640e-12, grad_fn=<MseLossBackward>)
# tensor(1.1979e-11, grad_fn=<MseLossBackward>)
# tensor(1.3452e-11, grad_fn=<MseLossBackward>)
# tensor(1.0090e-11, grad_fn=<MseLossBackward>)
# tensor(8.8158e-12, grad_fn=<MseLossBackward>)
# tensor(1.4702e-11, grad_fn=<MseLossBackward>)
# tensor(6.7455e-12, grad_fn=<MseLossBackward>)
# tensor(6.7414e-12, grad_fn=<MseLossBackward>)
# tensor(1.1409e-11, grad_fn=<MseLossBackward>)
# tensor(8.5711e-12, grad_fn=<MseLossBackward>)
# tensor(1.1388e-11, grad_fn=<MseLossBackward>)
# tensor(8.0980e-12, grad_fn=<MseLossBackward>)
# tensor(1.2899e-11, grad_fn=<MseLossBackward>)
# tensor(1.4789e-11, grad_fn=<MseLossBackward>)
# tensor(9.2733e-12, grad_fn=<MseLossBackward>)
# tensor(8.7973e-12, grad_fn=<MseLossBackward>)
# tensor(8.5764e-12, grad_fn=<MseLossBackward>)
# tensor(1.2427e-11, grad_fn=<MseLossBackward>)
# tensor(9.3870e-12, grad_fn=<MseLossBackward>)
# tensor(9.5284e-12, grad_fn=<MseLossBackward>)
# tensor(1.1993e-11, grad_fn=<MseLossBackward>)
# tensor(7.1426e-12, grad_fn=<MseLossBackward>)
# tensor(1.3345e-11, grad_fn=<MseLossBackward>)
# tensor(1.2201e-11, grad_fn=<MseLossBackward>)
# tensor(1.2757e-11, grad_fn=<MseLossBackward>)
# tensor(9.4667e-12, grad_fn=<MseLossBackward>)
# tensor(1.1206e-11, grad_fn=<MseLossBackward>)
# tensor(1.0349e-11, grad_fn=<MseLossBackward>)
# tensor(8.6690e-12, grad_fn=<MseLossBackward>)
# tensor(9.9131e-12, grad_fn=<MseLossBackward>)
# tensor(6.5873e-12, grad_fn=<MseLossBackward>)
# tensor(5.3683e-12, grad_fn=<MseLossBackward>)
# tensor(1.4256e-11, grad_fn=<MseLossBackward>)
# tensor(8.7351e-12, grad_fn=<MseLossBackward>)
# tensor(6.9208e-12, grad_fn=<MseLossBackward>)
# tensor(9.9083e-12, grad_fn=<MseLossBackward>)
# tensor(1.2524e-11, grad_fn=<MseLossBackward>)
# tensor(1.2429e-11, grad_fn=<MseLossBackward>)
# tensor(1.0711e-11, grad_fn=<MseLossBackward>)
# tensor(7.5624e-12, grad_fn=<MseLossBackward>)
# tensor(9.5367e-12, grad_fn=<MseLossBackward>)
# tensor(1.4413e-11, grad_fn=<MseLossBackward>)
# tensor(1.2940e-11, grad_fn=<MseLossBackward>)
# tensor(7.3284e-12, grad_fn=<MseLossBackward>)
# tensor(8.1925e-12, grad_fn=<MseLossBackward>)
# tensor(8.9679e-12, grad_fn=<MseLossBackward>)
# tensor(8.5224e-12, grad_fn=<MseLossBackward>)
# tensor(1.1365e-11, grad_fn=<MseLossBackward>)
# tensor(8.6623e-12, grad_fn=<MseLossBackward>)
# tensor(1.2270e-11, grad_fn=<MseLossBackward>)
# tensor(6.4379e-12, grad_fn=<MseLossBackward>)
# tensor(9.2985e-12, grad_fn=<MseLossBackward>)
# tensor(1.1127e-11, grad_fn=<MseLossBackward>)
# tensor(6.5185e-12, grad_fn=<MseLossBackward>)
# tensor(8.6387e-12, grad_fn=<MseLossBackward>)
# tensor(9.7438e-12, grad_fn=<MseLossBackward>)
# tensor(7.7208e-12, grad_fn=<MseLossBackward>)
# tensor(1.3417e-11, grad_fn=<MseLossBackward>)
# tensor(1.0163e-11, grad_fn=<MseLossBackward>)
# tensor(5.3431e-12, grad_fn=<MseLossBackward>)
# tensor(9.4820e-12, grad_fn=<MseLossBackward>)
# tensor(1.3000e-11, grad_fn=<MseLossBackward>)
# tensor(1.0745e-11, grad_fn=<MseLossBackward>)
# tensor(1.3377e-11, grad_fn=<MseLossBackward>)
# tensor(7.9335e-12, grad_fn=<MseLossBackward>)
# tensor(1.1048e-11, grad_fn=<MseLossBackward>)
# tensor(1.4837e-11, grad_fn=<MseLossBackward>)
# tensor(1.0870e-11, grad_fn=<MseLossBackward>)
# tensor(1.2414e-11, grad_fn=<MseLossBackward>)
# tensor(4.9827e-12, grad_fn=<MseLossBackward>)
# tensor(8.4023e-12, grad_fn=<MseLossBackward>)
# tensor(1.4928e-11, grad_fn=<MseLossBackward>)
# tensor(9.0946e-12, grad_fn=<MseLossBackward>)
# tensor(9.0354e-12, grad_fn=<MseLossBackward>)
# tensor(9.9775e-12, grad_fn=<MseLossBackward>)
# tensor(9.7417e-12, grad_fn=<MseLossBackward>)
# tensor(9.4928e-12, grad_fn=<MseLossBackward>)
# tensor(1.0598e-11, grad_fn=<MseLossBackward>)
# tensor(1.0010e-11, grad_fn=<MseLossBackward>)
# tensor(1.1051e-11, grad_fn=<MseLossBackward>)
# tensor(1.0858e-11, grad_fn=<MseLossBackward>)
# tensor(8.4370e-12, grad_fn=<MseLossBackward>)
# tensor(7.8791e-12, grad_fn=<MseLossBackward>)
# tensor(1.3149e-11, grad_fn=<MseLossBackward>)
# tensor(1.0206e-11, grad_fn=<MseLossBackward>)
# tensor(5.6354e-12, grad_fn=<MseLossBackward>)
# tensor(1.2362e-11, grad_fn=<MseLossBackward>)
# tensor(9.4088e-12, grad_fn=<MseLossBackward>)
# tensor(8.5235e-12, grad_fn=<MseLossBackward>)
# tensor(1.0037e-11, grad_fn=<MseLossBackward>)
# tensor(7.9758e-12, grad_fn=<MseLossBackward>)
# tensor(1.2266e-11, grad_fn=<MseLossBackward>)
# tensor(8.5290e-12, grad_fn=<MseLossBackward>)
# tensor(1.3309e-11, grad_fn=<MseLossBackward>)
# tensor(9.5653e-12, grad_fn=<MseLossBackward>)
# tensor(1.1020e-11, grad_fn=<MseLossBackward>)
# tensor(7.5057e-12, grad_fn=<MseLossBackward>)
# tensor(7.2320e-12, grad_fn=<MseLossBackward>)
# tensor(1.0719e-11, grad_fn=<MseLossBackward>)
# tensor(9.8193e-12, grad_fn=<MseLossBackward>)
# tensor(9.8133e-12, grad_fn=<MseLossBackward>)
# tensor(5.8780e-12, grad_fn=<MseLossBackward>)
# tensor(9.3056e-12, grad_fn=<MseLossBackward>)
# tensor(5.9303e-12, grad_fn=<MseLossBackward>)
# tensor(1.4685e-11, grad_fn=<MseLossBackward>)
# tensor(1.0372e-11, grad_fn=<MseLossBackward>)
# tensor(8.8415e-12, grad_fn=<MseLossBackward>)
# tensor(9.9359e-12, grad_fn=<MseLossBackward>)
# tensor(5.3567e-12, grad_fn=<MseLossBackward>)
# tensor(1.3101e-11, grad_fn=<MseLossBackward>)
# tensor(4.7500e-12, grad_fn=<MseLossBackward>)
# tensor(8.6740e-12, grad_fn=<MseLossBackward>)
# tensor(1.1995e-11, grad_fn=<MseLossBackward>)
# tensor(1.2822e-11, grad_fn=<MseLossBackward>)
# tensor(1.0661e-11, grad_fn=<MseLossBackward>)
# tensor(8.9123e-12, grad_fn=<MseLossBackward>)
# tensor(8.6017e-12, grad_fn=<MseLossBackward>)
# tensor(6.8640e-12, grad_fn=<MseLossBackward>)
# tensor(8.4942e-12, grad_fn=<MseLossBackward>)
# tensor(9.3213e-12, grad_fn=<MseLossBackward>)
# tensor(1.1791e-11, grad_fn=<MseLossBackward>)
# tensor(1.1319e-11, grad_fn=<MseLossBackward>)
# tensor(1.3548e-11, grad_fn=<MseLossBackward>)
# tensor(1.1674e-11, grad_fn=<MseLossBackward>)
# tensor(1.4934e-11, grad_fn=<MseLossBackward>)
# tensor(9.0860e-12, grad_fn=<MseLossBackward>)
# tensor(7.9186e-12, grad_fn=<MseLossBackward>)
# tensor(1.0703e-11, grad_fn=<MseLossBackward>)
# tensor(9.3146e-12, grad_fn=<MseLossBackward>)
# tensor(1.1897e-11, grad_fn=<MseLossBackward>)
# tensor(8.5077e-12, grad_fn=<MseLossBackward>)
# tensor(1.0873e-11, grad_fn=<MseLossBackward>)
# tensor(1.2145e-11, grad_fn=<MseLossBackward>)
# tensor(9.9669e-12, grad_fn=<MseLossBackward>)
# tensor(1.1173e-11, grad_fn=<MseLossBackward>)
# tensor(1.2177e-11, grad_fn=<MseLossBackward>)
# tensor(9.7333e-12, grad_fn=<MseLossBackward>)
# tensor(1.0598e-11, grad_fn=<MseLossBackward>)
# tensor(8.1047e-12, grad_fn=<MseLossBackward>)
# tensor(1.4224e-11, grad_fn=<MseLossBackward>)
# tensor(1.0155e-11, grad_fn=<MseLossBackward>)
# tensor(1.2046e-11, grad_fn=<MseLossBackward>)
# tensor(1.0473e-11, grad_fn=<MseLossBackward>)
# tensor(9.9612e-12, grad_fn=<MseLossBackward>)
# tensor(6.3017e-12, grad_fn=<MseLossBackward>)
# tensor(1.0713e-11, grad_fn=<MseLossBackward>)
# tensor(8.6695e-12, grad_fn=<MseLossBackward>)
# tensor(9.7437e-12, grad_fn=<MseLossBackward>)
# tensor(1.0963e-11, grad_fn=<MseLossBackward>)
# tensor(1.0618e-11, grad_fn=<MseLossBackward>)
# tensor(1.4942e-11, grad_fn=<MseLossBackward>)
# tensor(1.0236e-11, grad_fn=<MseLossBackward>)
# tensor(1.2569e-11, grad_fn=<MseLossBackward>)
# tensor(9.9533e-12, grad_fn=<MseLossBackward>)
# tensor(1.0001e-11, grad_fn=<MseLossBackward>)
# tensor(1.1166e-11, grad_fn=<MseLossBackward>)
# tensor(8.1492e-12, grad_fn=<MseLossBackward>)
# tensor(1.1491e-11, grad_fn=<MseLossBackward>)
# tensor(1.1467e-11, grad_fn=<MseLossBackward>)
# tensor(6.4097e-12, grad_fn=<MseLossBackward>)
# tensor(9.8050e-12, grad_fn=<MseLossBackward>)
# tensor(6.1691e-12, grad_fn=<MseLossBackward>)
# tensor(1.3664e-11, grad_fn=<MseLossBackward>)
# tensor(1.3678e-11, grad_fn=<MseLossBackward>)
# tensor(1.5000e-11, grad_fn=<MseLossBackward>)
# tensor(1.1431e-11, grad_fn=<MseLossBackward>)
# tensor(1.2217e-11, grad_fn=<MseLossBackward>)
# tensor(9.2491e-12, grad_fn=<MseLossBackward>)
# tensor(1.5521e-11, grad_fn=<MseLossBackward>)
# tensor(9.6807e-12, grad_fn=<MseLossBackward>)
# tensor(1.2475e-11, grad_fn=<MseLossBackward>)
# tensor(8.4820e-12, grad_fn=<MseLossBackward>)
# tensor(7.8397e-12, grad_fn=<MseLossBackward>)
# tensor(1.2976e-11, grad_fn=<MseLossBackward>)
# tensor(1.0647e-11, grad_fn=<MseLossBackward>)
# tensor(1.0642e-11, grad_fn=<MseLossBackward>)
# tensor(8.9120e-12, grad_fn=<MseLossBackward>)
# tensor(1.1515e-11, grad_fn=<MseLossBackward>)
# tensor(1.1470e-11, grad_fn=<MseLossBackward>)
# tensor(9.6096e-12, grad_fn=<MseLossBackward>)
# tensor(9.2866e-12, grad_fn=<MseLossBackward>)
# tensor(1.0425e-11, grad_fn=<MseLossBackward>)
# tensor(1.0025e-11, grad_fn=<MseLossBackward>)
# tensor(9.0622e-12, grad_fn=<MseLossBackward>)
# tensor(8.4843e-12, grad_fn=<MseLossBackward>)
# tensor(8.0023e-12, grad_fn=<MseLossBackward>)
# tensor(1.1397e-11, grad_fn=<MseLossBackward>)
# tensor(7.3499e-12, grad_fn=<MseLossBackward>)
# tensor(1.2393e-11, grad_fn=<MseLossBackward>)
# tensor(1.1463e-11, grad_fn=<MseLossBackward>)
# tensor(9.6630e-12, grad_fn=<MseLossBackward>)
# tensor(1.2516e-11, grad_fn=<MseLossBackward>)
# tensor(1.3713e-11, grad_fn=<MseLossBackward>)
# tensor(9.2923e-12, grad_fn=<MseLossBackward>)
# tensor(9.0269e-12, grad_fn=<MseLossBackward>)
# tensor(1.1588e-11, grad_fn=<MseLossBackward>)
# tensor(6.9568e-12, grad_fn=<MseLossBackward>)
# tensor(1.0456e-11, grad_fn=<MseLossBackward>)
# tensor(1.1350e-11, grad_fn=<MseLossBackward>)
# tensor(7.6991e-12, grad_fn=<MseLossBackward>)
# tensor(9.5102e-12, grad_fn=<MseLossBackward>)
# tensor(7.9397e-12, grad_fn=<MseLossBackward>)
# tensor(6.3110e-12, grad_fn=<MseLossBackward>)
# tensor(8.1215e-12, grad_fn=<MseLossBackward>)
# tensor(5.6984e-12, grad_fn=<MseLossBackward>)
# tensor(9.5863e-12, grad_fn=<MseLossBackward>)
# tensor(7.0870e-12, grad_fn=<MseLossBackward>)
# tensor(1.1036e-11, grad_fn=<MseLossBackward>)
# tensor(7.8453e-12, grad_fn=<MseLossBackward>)
# tensor(9.4639e-12, grad_fn=<MseLossBackward>)
# tensor(6.7482e-12, grad_fn=<MseLossBackward>)
# tensor(1.4132e-11, grad_fn=<MseLossBackward>)
# tensor(5.7596e-12, grad_fn=<MseLossBackward>)
# tensor(1.1741e-11, grad_fn=<MseLossBackward>)
# tensor(1.0944e-11, grad_fn=<MseLossBackward>)
# tensor(1.1112e-11, grad_fn=<MseLossBackward>)
# tensor(7.7957e-12, grad_fn=<MseLossBackward>)
# tensor(1.3350e-11, grad_fn=<MseLossBackward>)
# tensor(1.0780e-11, grad_fn=<MseLossBackward>)
# tensor(7.6122e-12, grad_fn=<MseLossBackward>)
# tensor(8.1846e-12, grad_fn=<MseLossBackward>)
# tensor(1.2098e-11, grad_fn=<MseLossBackward>)
# tensor(1.2148e-11, grad_fn=<MseLossBackward>)
# tensor(6.0575e-12, grad_fn=<MseLossBackward>)
# tensor(1.0249e-11, grad_fn=<MseLossBackward>)
# tensor(1.1353e-11, grad_fn=<MseLossBackward>)
# tensor(6.5617e-12, grad_fn=<MseLossBackward>)
# tensor(1.5111e-11, grad_fn=<MseLossBackward>)
# tensor(1.1347e-11, grad_fn=<MseLossBackward>)
# tensor(8.8244e-12, grad_fn=<MseLossBackward>)
# tensor(1.0519e-11, grad_fn=<MseLossBackward>)
# tensor(1.3315e-11, grad_fn=<MseLossBackward>)
# tensor(1.0168e-11, grad_fn=<MseLossBackward>)
# tensor(1.7864e-11, grad_fn=<MseLossBackward>)
# tensor(9.1348e-12, grad_fn=<MseLossBackward>)
# tensor(1.2639e-11, grad_fn=<MseLossBackward>)
# tensor(8.8611e-12, grad_fn=<MseLossBackward>)
# tensor(1.2113e-11, grad_fn=<MseLossBackward>)
# tensor(8.5817e-12, grad_fn=<MseLossBackward>)
# tensor(6.1481e-12, grad_fn=<MseLossBackward>)
# tensor(1.1413e-11, grad_fn=<MseLossBackward>)
# tensor(7.2749e-12, grad_fn=<MseLossBackward>)
# tensor(8.3845e-12, grad_fn=<MseLossBackward>)
# tensor(1.2866e-11, grad_fn=<MseLossBackward>)
# tensor(1.0568e-11, grad_fn=<MseLossBackward>)
# tensor(7.7314e-12, grad_fn=<MseLossBackward>)
# tensor(1.2967e-11, grad_fn=<MseLossBackward>)
# tensor(1.1956e-11, grad_fn=<MseLossBackward>)
# tensor(6.0397e-12, grad_fn=<MseLossBackward>)
# tensor(9.0680e-12, grad_fn=<MseLossBackward>)
# tensor(1.1056e-11, grad_fn=<MseLossBackward>)
# tensor(7.0058e-12, grad_fn=<MseLossBackward>)
# tensor(6.5252e-12, grad_fn=<MseLossBackward>)
# tensor(1.0432e-11, grad_fn=<MseLossBackward>)
# tensor(8.7025e-12, grad_fn=<MseLossBackward>)
# tensor(8.0146e-12, grad_fn=<MseLossBackward>)
# tensor(8.4055e-12, grad_fn=<MseLossBackward>)
# tensor(1.0918e-11, grad_fn=<MseLossBackward>)
# tensor(8.0002e-12, grad_fn=<MseLossBackward>)
# tensor(1.1107e-11, grad_fn=<MseLossBackward>)
# tensor(1.3133e-11, grad_fn=<MseLossBackward>)
# tensor(1.1617e-11, grad_fn=<MseLossBackward>)
# tensor(9.6315e-12, grad_fn=<MseLossBackward>)
# tensor(7.2364e-12, grad_fn=<MseLossBackward>)
# tensor(1.2633e-11, grad_fn=<MseLossBackward>)
# tensor(8.5944e-12, grad_fn=<MseLossBackward>)
# tensor(1.1792e-11, grad_fn=<MseLossBackward>)
# tensor(6.0786e-12, grad_fn=<MseLossBackward>)
# tensor(1.7645e-11, grad_fn=<MseLossBackward>)
# tensor(6.5360e-12, grad_fn=<MseLossBackward>)
# tensor(7.4975e-12, grad_fn=<MseLossBackward>)
# tensor(1.0890e-11, grad_fn=<MseLossBackward>)
# tensor(1.5234e-11, grad_fn=<MseLossBackward>)
# tensor(1.3269e-11, grad_fn=<MseLossBackward>)
# tensor(1.2573e-11, grad_fn=<MseLossBackward>)
# tensor(8.6292e-12, grad_fn=<MseLossBackward>)
# tensor(1.5152e-11, grad_fn=<MseLossBackward>)
# tensor(1.2704e-11, grad_fn=<MseLossBackward>)
# tensor(8.4715e-12, grad_fn=<MseLossBackward>)
# tensor(8.3380e-12, grad_fn=<MseLossBackward>)
# tensor(1.0284e-11, grad_fn=<MseLossBackward>)
# tensor(5.9180e-12, grad_fn=<MseLossBackward>)
# tensor(1.0341e-11, grad_fn=<MseLossBackward>)
# tensor(8.4766e-12, grad_fn=<MseLossBackward>)
# tensor(4.6172e-12, grad_fn=<MseLossBackward>)
# tensor(9.4050e-12, grad_fn=<MseLossBackward>)
# tensor(1.5722e-11, grad_fn=<MseLossBackward>)
# tensor(9.4038e-12, grad_fn=<MseLossBackward>)
# tensor(9.9175e-12, grad_fn=<MseLossBackward>)
# tensor(8.2044e-12, grad_fn=<MseLossBackward>)
# tensor(1.2337e-11, grad_fn=<MseLossBackward>)
# tensor(8.6737e-12, grad_fn=<MseLossBackward>)
# tensor(6.6956e-12, grad_fn=<MseLossBackward>)
# tensor(1.3324e-11, grad_fn=<MseLossBackward>)
# tensor(1.0415e-11, grad_fn=<MseLossBackward>)
# tensor(1.2232e-11, grad_fn=<MseLossBackward>)
# tensor(1.1769e-11, grad_fn=<MseLossBackward>)
# tensor(7.8045e-12, grad_fn=<MseLossBackward>)
# tensor(1.2700e-11, grad_fn=<MseLossBackward>)
# tensor(1.3168e-11, grad_fn=<MseLossBackward>)
# tensor(8.1814e-12, grad_fn=<MseLossBackward>)
# tensor(8.3053e-12, grad_fn=<MseLossBackward>)
# tensor(7.8388e-12, grad_fn=<MseLossBackward>)
# tensor(1.0310e-11, grad_fn=<MseLossBackward>)
# tensor(8.7099e-12, grad_fn=<MseLossBackward>)
# tensor(1.1895e-11, grad_fn=<MseLossBackward>)
# tensor(5.8626e-12, grad_fn=<MseLossBackward>)
# tensor(1.1750e-11, grad_fn=<MseLossBackward>)
# tensor(7.3398e-12, grad_fn=<MseLossBackward>)
# tensor(1.1553e-11, grad_fn=<MseLossBackward>)
# tensor(9.6457e-12, grad_fn=<MseLossBackward>)
# tensor(1.1338e-11, grad_fn=<MseLossBackward>)
# tensor(1.0342e-11, grad_fn=<MseLossBackward>)
# tensor(1.1161e-11, grad_fn=<MseLossBackward>)
# tensor(9.7015e-12, grad_fn=<MseLossBackward>)
# tensor(8.5522e-12, grad_fn=<MseLossBackward>)
# tensor(1.2154e-11, grad_fn=<MseLossBackward>)
# tensor(7.0143e-12, grad_fn=<MseLossBackward>)
# tensor(1.3516e-11, grad_fn=<MseLossBackward>)
# tensor(8.3145e-12, grad_fn=<MseLossBackward>)
# tensor(4.6495e-12, grad_fn=<MseLossBackward>)
# tensor(1.0950e-11, grad_fn=<MseLossBackward>)
# tensor(1.2955e-11, grad_fn=<MseLossBackward>)
# tensor(1.0255e-11, grad_fn=<MseLossBackward>)
# tensor(8.5362e-12, grad_fn=<MseLossBackward>)
# tensor(7.2636e-12, grad_fn=<MseLossBackward>)
# tensor(9.0568e-12, grad_fn=<MseLossBackward>)
# tensor(1.1276e-11, grad_fn=<MseLossBackward>)
# tensor(8.0977e-12, grad_fn=<MseLossBackward>)
# tensor(1.1731e-11, grad_fn=<MseLossBackward>)
# tensor(1.2132e-11, grad_fn=<MseLossBackward>)
# tensor(1.1964e-11, grad_fn=<MseLossBackward>)
# tensor(1.3406e-11, grad_fn=<MseLossBackward>)
# tensor(9.1492e-12, grad_fn=<MseLossBackward>)
# tensor(6.1759e-12, grad_fn=<MseLossBackward>)
# tensor(1.0937e-11, grad_fn=<MseLossBackward>)
# tensor(8.6642e-12, grad_fn=<MseLossBackward>)
# tensor(1.5880e-11, grad_fn=<MseLossBackward>)
# tensor(7.9663e-12, grad_fn=<MseLossBackward>)
# tensor(8.4479e-12, grad_fn=<MseLossBackward>)
# tensor(1.5244e-11, grad_fn=<MseLossBackward>)
# tensor(1.0776e-11, grad_fn=<MseLossBackward>)
# tensor(1.1494e-11, grad_fn=<MseLossBackward>)
# tensor(1.0715e-11, grad_fn=<MseLossBackward>)
# tensor(7.6257e-12, grad_fn=<MseLossBackward>)
# tensor(1.3379e-11, grad_fn=<MseLossBackward>)
# tensor(1.1038e-11, grad_fn=<MseLossBackward>)
# tensor(1.1641e-11, grad_fn=<MseLossBackward>)
# tensor(1.0615e-11, grad_fn=<MseLossBackward>)
# tensor(9.2839e-12, grad_fn=<MseLossBackward>)
# tensor(1.1064e-11, grad_fn=<MseLossBackward>)
# tensor(5.4814e-12, grad_fn=<MseLossBackward>)
# tensor(1.0400e-11, grad_fn=<MseLossBackward>)
# tensor(1.1910e-11, grad_fn=<MseLossBackward>)
# tensor(1.0383e-11, grad_fn=<MseLossBackward>)
# tensor(9.5278e-12, grad_fn=<MseLossBackward>)
# tensor(1.2183e-11, grad_fn=<MseLossBackward>)
# tensor(1.1905e-11, grad_fn=<MseLossBackward>)
# tensor(9.9431e-12, grad_fn=<MseLossBackward>)
# tensor(1.2590e-11, grad_fn=<MseLossBackward>)
# tensor(7.1234e-12, grad_fn=<MseLossBackward>)
# tensor(7.0926e-12, grad_fn=<MseLossBackward>)
# tensor(1.0761e-11, grad_fn=<MseLossBackward>)
# tensor(7.7253e-12, grad_fn=<MseLossBackward>)
# tensor(1.2227e-11, grad_fn=<MseLossBackward>)
# tensor(1.2626e-11, grad_fn=<MseLossBackward>)
# tensor(8.7283e-12, grad_fn=<MseLossBackward>)
# tensor(1.2565e-11, grad_fn=<MseLossBackward>)
# tensor(1.2517e-11, grad_fn=<MseLossBackward>)
# tensor(1.3287e-11, grad_fn=<MseLossBackward>)
# tensor(1.0843e-11, grad_fn=<MseLossBackward>)
# tensor(8.3770e-12, grad_fn=<MseLossBackward>)
# tensor(6.5795e-12, grad_fn=<MseLossBackward>)
# tensor(1.3089e-11, grad_fn=<MseLossBackward>)
# tensor(7.8545e-12, grad_fn=<MseLossBackward>)
# tensor(1.1250e-11, grad_fn=<MseLossBackward>)
# tensor(9.1779e-12, grad_fn=<MseLossBackward>)
# tensor(9.7109e-12, grad_fn=<MseLossBackward>)
# tensor(1.1826e-11, grad_fn=<MseLossBackward>)
# tensor(1.2949e-11, grad_fn=<MseLossBackward>)
# tensor(1.2960e-11, grad_fn=<MseLossBackward>)
# tensor(7.1606e-12, grad_fn=<MseLossBackward>)
# tensor(1.1156e-11, grad_fn=<MseLossBackward>)
# tensor(1.0820e-11, grad_fn=<MseLossBackward>)
# tensor(7.0852e-12, grad_fn=<MseLossBackward>)
# tensor(6.4216e-12, grad_fn=<MseLossBackward>)
# tensor(7.7984e-12, grad_fn=<MseLossBackward>)
# tensor(1.1299e-11, grad_fn=<MseLossBackward>)
# tensor(1.1822e-11, grad_fn=<MseLossBackward>)
# tensor(5.6570e-12, grad_fn=<MseLossBackward>)
# tensor(9.5671e-12, grad_fn=<MseLossBackward>)
# tensor(1.0580e-11, grad_fn=<MseLossBackward>)
# tensor(1.3993e-11, grad_fn=<MseLossBackward>)
# tensor(7.4462e-12, grad_fn=<MseLossBackward>)
# tensor(1.5136e-11, grad_fn=<MseLossBackward>)
# tensor(7.8458e-12, grad_fn=<MseLossBackward>)
# tensor(1.1883e-11, grad_fn=<MseLossBackward>)
# tensor(1.5287e-11, grad_fn=<MseLossBackward>)
# tensor(7.8619e-12, grad_fn=<MseLossBackward>)
# tensor(8.5276e-12, grad_fn=<MseLossBackward>)
# tensor(1.3471e-11, grad_fn=<MseLossBackward>)
# tensor(7.6290e-12, grad_fn=<MseLossBackward>)
# tensor(9.7402e-12, grad_fn=<MseLossBackward>)
# tensor(1.2046e-11, grad_fn=<MseLossBackward>)
# tensor(5.7446e-12, grad_fn=<MseLossBackward>)
# tensor(1.0224e-11, grad_fn=<MseLossBackward>)
# tensor(1.3536e-11, grad_fn=<MseLossBackward>)
# tensor(1.3853e-11, grad_fn=<MseLossBackward>)
# tensor(1.0048e-11, grad_fn=<MseLossBackward>)
# tensor(1.0132e-11, grad_fn=<MseLossBackward>)
# tensor(9.5021e-12, grad_fn=<MseLossBackward>)
# tensor(1.3260e-11, grad_fn=<MseLossBackward>)
# tensor(1.5249e-11, grad_fn=<MseLossBackward>)
# tensor(1.4645e-11, grad_fn=<MseLossBackward>)
# tensor(8.4488e-12, grad_fn=<MseLossBackward>)
# tensor(1.2877e-11, grad_fn=<MseLossBackward>)
# tensor(1.4468e-11, grad_fn=<MseLossBackward>)
# tensor(8.3474e-12, grad_fn=<MseLossBackward>)
# tensor(1.3472e-11, grad_fn=<MseLossBackward>)
# tensor(8.7735e-12, grad_fn=<MseLossBackward>)
# tensor(5.7356e-12, grad_fn=<MseLossBackward>)
# tensor(1.4872e-11, grad_fn=<MseLossBackward>)
# tensor(1.0336e-11, grad_fn=<MseLossBackward>)
# tensor(5.7376e-12, grad_fn=<MseLossBackward>)
# tensor(1.1525e-11, grad_fn=<MseLossBackward>)
# tensor(7.0910e-12, grad_fn=<MseLossBackward>)
# tensor(1.3910e-11, grad_fn=<MseLossBackward>)
# tensor(5.8291e-12, grad_fn=<MseLossBackward>)
# tensor(1.2661e-11, grad_fn=<MseLossBackward>)
# tensor(1.4250e-11, grad_fn=<MseLossBackward>)
# tensor(1.3593e-11, grad_fn=<MseLossBackward>)
# tensor(1.0245e-11, grad_fn=<MseLossBackward>)
# tensor(1.0628e-11, grad_fn=<MseLossBackward>)
# tensor(1.3046e-11, grad_fn=<MseLossBackward>)
# tensor(8.0247e-12, grad_fn=<MseLossBackward>)
# tensor(1.0940e-11, grad_fn=<MseLossBackward>)
# tensor(1.0612e-11, grad_fn=<MseLossBackward>)
# tensor(9.9570e-12, grad_fn=<MseLossBackward>)
# tensor(1.0517e-11, grad_fn=<MseLossBackward>)
# tensor(1.4534e-11, grad_fn=<MseLossBackward>)
# tensor(1.1916e-11, grad_fn=<MseLossBackward>)
# tensor(1.2280e-11, grad_fn=<MseLossBackward>)
# tensor(1.0916e-11, grad_fn=<MseLossBackward>)
# tensor(8.0558e-12, grad_fn=<MseLossBackward>)
# tensor(9.3443e-12, grad_fn=<MseLossBackward>)
# tensor(1.3130e-11, grad_fn=<MseLossBackward>)
# tensor(9.5232e-12, grad_fn=<MseLossBackward>)
# tensor(1.2508e-11, grad_fn=<MseLossBackward>)
# tensor(1.4027e-11, grad_fn=<MseLossBackward>)
# tensor(1.0723e-11, grad_fn=<MseLossBackward>)
# tensor(9.5951e-12, grad_fn=<MseLossBackward>)
# tensor(5.0136e-12, grad_fn=<MseLossBackward>)
# tensor(6.6998e-12, grad_fn=<MseLossBackward>)
# tensor(8.1124e-12, grad_fn=<MseLossBackward>)
# tensor(7.6071e-12, grad_fn=<MseLossBackward>)
# tensor(9.1924e-12, grad_fn=<MseLossBackward>)
# tensor(1.0282e-11, grad_fn=<MseLossBackward>)
# tensor(1.1487e-11, grad_fn=<MseLossBackward>)
# tensor(8.3446e-12, grad_fn=<MseLossBackward>)
# tensor(8.4557e-12, grad_fn=<MseLossBackward>)
# tensor(1.1094e-11, grad_fn=<MseLossBackward>)
# tensor(9.0577e-12, grad_fn=<MseLossBackward>)
# tensor(1.4786e-11, grad_fn=<MseLossBackward>)
# tensor(1.2581e-11, grad_fn=<MseLossBackward>)
# tensor(1.4204e-11, grad_fn=<MseLossBackward>)
# tensor(7.3852e-12, grad_fn=<MseLossBackward>)
# tensor(9.4159e-12, grad_fn=<MseLossBackward>)
# tensor(7.8211e-12, grad_fn=<MseLossBackward>)
# tensor(9.1860e-12, grad_fn=<MseLossBackward>)
# tensor(1.1930e-11, grad_fn=<MseLossBackward>)
# tensor(9.5254e-12, grad_fn=<MseLossBackward>)
# tensor(1.1895e-11, grad_fn=<MseLossBackward>)
# tensor(1.1697e-11, grad_fn=<MseLossBackward>)
# tensor(1.2233e-11, grad_fn=<MseLossBackward>)
# tensor(7.3273e-12, grad_fn=<MseLossBackward>)
# tensor(9.5409e-12, grad_fn=<MseLossBackward>)
# tensor(7.8478e-12, grad_fn=<MseLossBackward>)
# tensor(1.1962e-11, grad_fn=<MseLossBackward>)
# tensor(7.3715e-12, grad_fn=<MseLossBackward>)
# tensor(8.0453e-12, grad_fn=<MseLossBackward>)
# tensor(1.2847e-11, grad_fn=<MseLossBackward>)
# tensor(8.5904e-12, grad_fn=<MseLossBackward>)
# tensor(8.6165e-12, grad_fn=<MseLossBackward>)
# tensor(8.4509e-12, grad_fn=<MseLossBackward>)
# tensor(1.2455e-11, grad_fn=<MseLossBackward>)
# tensor(1.2084e-11, grad_fn=<MseLossBackward>)
# tensor(1.2984e-11, grad_fn=<MseLossBackward>)
# tensor(1.1766e-11, grad_fn=<MseLossBackward>)
# tensor(1.1778e-11, grad_fn=<MseLossBackward>)
# tensor(1.0730e-11, grad_fn=<MseLossBackward>)
# tensor(1.1160e-11, grad_fn=<MseLossBackward>)
# tensor(6.0972e-12, grad_fn=<MseLossBackward>)
# tensor(1.1146e-11, grad_fn=<MseLossBackward>)
# tensor(1.1900e-11, grad_fn=<MseLossBackward>)
# tensor(1.4885e-11, grad_fn=<MseLossBackward>)
# tensor(1.5255e-11, grad_fn=<MseLossBackward>)
# tensor(5.7885e-12, grad_fn=<MseLossBackward>)
# tensor(9.4822e-12, grad_fn=<MseLossBackward>)
# tensor(9.9023e-12, grad_fn=<MseLossBackward>)
# tensor(9.4447e-12, grad_fn=<MseLossBackward>)
# tensor(9.3752e-12, grad_fn=<MseLossBackward>)
# tensor(4.6401e-12, grad_fn=<MseLossBackward>)
# tensor(4.8564e-12, grad_fn=<MseLossBackward>)
# tensor(7.4093e-12, grad_fn=<MseLossBackward>)
# tensor(7.7983e-12, grad_fn=<MseLossBackward>)
# tensor(7.8467e-12, grad_fn=<MseLossBackward>)
# tensor(6.3990e-12, grad_fn=<MseLossBackward>)
# tensor(1.3202e-11, grad_fn=<MseLossBackward>)
# tensor(1.1333e-11, grad_fn=<MseLossBackward>)
# tensor(1.0678e-11, grad_fn=<MseLossBackward>)
# tensor(7.2335e-12, grad_fn=<MseLossBackward>)
# tensor(1.0640e-11, grad_fn=<MseLossBackward>)
# tensor(8.0574e-12, grad_fn=<MseLossBackward>)
# tensor(1.0956e-11, grad_fn=<MseLossBackward>)
# tensor(8.3360e-12, grad_fn=<MseLossBackward>)
# tensor(1.1198e-11, grad_fn=<MseLossBackward>)
# tensor(7.0170e-12, grad_fn=<MseLossBackward>)
# tensor(1.1331e-11, grad_fn=<MseLossBackward>)
# tensor(1.2781e-11, grad_fn=<MseLossBackward>)
# tensor(8.8341e-12, grad_fn=<MseLossBackward>)
# tensor(1.4216e-11, grad_fn=<MseLossBackward>)
# tensor(1.4139e-11, grad_fn=<MseLossBackward>)
# tensor(9.4953e-12, grad_fn=<MseLossBackward>)
# tensor(1.2067e-11, grad_fn=<MseLossBackward>)
# tensor(1.1935e-11, grad_fn=<MseLossBackward>)
# tensor(9.9952e-12, grad_fn=<MseLossBackward>)
# tensor(8.9917e-12, grad_fn=<MseLossBackward>)
# tensor(1.3971e-11, grad_fn=<MseLossBackward>)
# tensor(1.5539e-11, grad_fn=<MseLossBackward>)
# tensor(8.5997e-12, grad_fn=<MseLossBackward>)
# tensor(8.9515e-12, grad_fn=<MseLossBackward>)
# tensor(6.6462e-12, grad_fn=<MseLossBackward>)
# tensor(1.3435e-11, grad_fn=<MseLossBackward>)
# tensor(9.4888e-12, grad_fn=<MseLossBackward>)
# tensor(9.4452e-12, grad_fn=<MseLossBackward>)
# tensor(1.3063e-11, grad_fn=<MseLossBackward>)
# tensor(1.2241e-11, grad_fn=<MseLossBackward>)
# tensor(1.3595e-11, grad_fn=<MseLossBackward>)
# tensor(1.2882e-11, grad_fn=<MseLossBackward>)
# tensor(8.8612e-12, grad_fn=<MseLossBackward>)
# tensor(1.1031e-11, grad_fn=<MseLossBackward>)
# tensor(5.1047e-12, grad_fn=<MseLossBackward>)
# tensor(1.1420e-11, grad_fn=<MseLossBackward>)
# tensor(1.1221e-11, grad_fn=<MseLossBackward>)
# tensor(9.8326e-12, grad_fn=<MseLossBackward>)
# tensor(1.3136e-11, grad_fn=<MseLossBackward>)
# tensor(1.3602e-11, grad_fn=<MseLossBackward>)
# tensor(1.1154e-11, grad_fn=<MseLossBackward>)
# tensor(1.4721e-11, grad_fn=<MseLossBackward>)
# tensor(6.3531e-12, grad_fn=<MseLossBackward>)
# tensor(8.1905e-12, grad_fn=<MseLossBackward>)
# tensor(8.1602e-12, grad_fn=<MseLossBackward>)
# tensor(8.1690e-12, grad_fn=<MseLossBackward>)
# tensor(1.1009e-11, grad_fn=<MseLossBackward>)
# tensor(9.1859e-12, grad_fn=<MseLossBackward>)
# tensor(6.7173e-12, grad_fn=<MseLossBackward>)
# tensor(7.1160e-12, grad_fn=<MseLossBackward>)
# tensor(8.0552e-12, grad_fn=<MseLossBackward>)
# tensor(9.3660e-12, grad_fn=<MseLossBackward>)
# tensor(8.9798e-12, grad_fn=<MseLossBackward>)
# tensor(7.6113e-12, grad_fn=<MseLossBackward>)
# tensor(1.2525e-11, grad_fn=<MseLossBackward>)
# tensor(9.9135e-12, grad_fn=<MseLossBackward>)
# tensor(7.8705e-12, grad_fn=<MseLossBackward>)
# tensor(9.6117e-12, grad_fn=<MseLossBackward>)
# tensor(9.0236e-12, grad_fn=<MseLossBackward>)
# tensor(6.5235e-12, grad_fn=<MseLossBackward>)
# tensor(1.0870e-11, grad_fn=<MseLossBackward>)
# tensor(1.4386e-11, grad_fn=<MseLossBackward>)
# tensor(8.6034e-12, grad_fn=<MseLossBackward>)
# tensor(7.2907e-12, grad_fn=<MseLossBackward>)
# tensor(1.2369e-11, grad_fn=<MseLossBackward>)
# tensor(7.6492e-12, grad_fn=<MseLossBackward>)
# tensor(8.3342e-12, grad_fn=<MseLossBackward>)
# tensor(1.4941e-11, grad_fn=<MseLossBackward>)
# tensor(8.8494e-12, grad_fn=<MseLossBackward>)
# tensor(1.0397e-11, grad_fn=<MseLossBackward>)
# tensor(1.3532e-11, grad_fn=<MseLossBackward>)
# tensor(5.9181e-12, grad_fn=<MseLossBackward>)
# tensor(1.0245e-11, grad_fn=<MseLossBackward>)
# tensor(7.1372e-12, grad_fn=<MseLossBackward>)
# tensor(9.2519e-12, grad_fn=<MseLossBackward>)
# tensor(6.0858e-12, grad_fn=<MseLossBackward>)
# tensor(1.1241e-11, grad_fn=<MseLossBackward>)
# tensor(1.1127e-11, grad_fn=<MseLossBackward>)
# tensor(5.6260e-12, grad_fn=<MseLossBackward>)
# tensor(9.1824e-12, grad_fn=<MseLossBackward>)
# tensor(1.2104e-11, grad_fn=<MseLossBackward>)
# tensor(9.4561e-12, grad_fn=<MseLossBackward>)
# tensor(8.3299e-12, grad_fn=<MseLossBackward>)
# tensor(6.3582e-12, grad_fn=<MseLossBackward>)
# tensor(9.5984e-12, grad_fn=<MseLossBackward>)
# tensor(7.0759e-12, grad_fn=<MseLossBackward>)
# tensor(7.2644e-12, grad_fn=<MseLossBackward>)
# tensor(1.0295e-11, grad_fn=<MseLossBackward>)
# tensor(6.8292e-12, grad_fn=<MseLossBackward>)
# tensor(9.9061e-12, grad_fn=<MseLossBackward>)
# tensor(1.2273e-11, grad_fn=<MseLossBackward>)
# tensor(1.0941e-11, grad_fn=<MseLossBackward>)
# tensor(9.2961e-12, grad_fn=<MseLossBackward>)
# tensor(8.4416e-12, grad_fn=<MseLossBackward>)
# tensor(1.2796e-11, grad_fn=<MseLossBackward>)
# tensor(4.8445e-12, grad_fn=<MseLossBackward>)
# tensor(8.1333e-12, grad_fn=<MseLossBackward>)
# tensor(1.0512e-11, grad_fn=<MseLossBackward>)
# tensor(9.1849e-12, grad_fn=<MseLossBackward>)
# tensor(9.3019e-12, grad_fn=<MseLossBackward>)
# tensor(6.7603e-12, grad_fn=<MseLossBackward>)
# tensor(7.5650e-12, grad_fn=<MseLossBackward>)
# tensor(1.0393e-11, grad_fn=<MseLossBackward>)
# tensor(9.8305e-12, grad_fn=<MseLossBackward>)
# tensor(9.8538e-12, grad_fn=<MseLossBackward>)
# tensor(1.0608e-11, grad_fn=<MseLossBackward>)
# tensor(1.0734e-11, grad_fn=<MseLossBackward>)
# tensor(6.7027e-12, grad_fn=<MseLossBackward>)
# tensor(7.3698e-12, grad_fn=<MseLossBackward>)
# tensor(1.0627e-11, grad_fn=<MseLossBackward>)
# tensor(1.0004e-11, grad_fn=<MseLossBackward>)
# tensor(1.0898e-11, grad_fn=<MseLossBackward>)
# tensor(8.2943e-12, grad_fn=<MseLossBackward>)
# tensor(8.8714e-12, grad_fn=<MseLossBackward>)
# tensor(4.5160e-12, grad_fn=<MseLossBackward>)
# tensor(7.8946e-12, grad_fn=<MseLossBackward>)
# tensor(7.5745e-12, grad_fn=<MseLossBackward>)
# tensor(6.3727e-12, grad_fn=<MseLossBackward>)
# tensor(1.1538e-11, grad_fn=<MseLossBackward>)
# tensor(8.5311e-12, grad_fn=<MseLossBackward>)
# tensor(6.2665e-12, grad_fn=<MseLossBackward>)
# tensor(1.2853e-11, grad_fn=<MseLossBackward>)
# tensor(7.3369e-12, grad_fn=<MseLossBackward>)
# tensor(1.0330e-11, grad_fn=<MseLossBackward>)
# tensor(9.9056e-12, grad_fn=<MseLossBackward>)
# tensor(1.1825e-11, grad_fn=<MseLossBackward>)
# tensor(8.2155e-12, grad_fn=<MseLossBackward>)
# tensor(1.0217e-11, grad_fn=<MseLossBackward>)
# tensor(1.1187e-11, grad_fn=<MseLossBackward>)
# tensor(8.6548e-12, grad_fn=<MseLossBackward>)
# tensor(8.2342e-12, grad_fn=<MseLossBackward>)
# tensor(5.3474e-12, grad_fn=<MseLossBackward>)
# tensor(1.4211e-11, grad_fn=<MseLossBackward>)
# tensor(1.1390e-11, grad_fn=<MseLossBackward>)
# tensor(9.2246e-12, grad_fn=<MseLossBackward>)
# tensor(9.6377e-12, grad_fn=<MseLossBackward>)
# tensor(4.6208e-12, grad_fn=<MseLossBackward>)
# tensor(7.2543e-12, grad_fn=<MseLossBackward>)
# tensor(8.4774e-12, grad_fn=<MseLossBackward>)
# tensor(9.9316e-12, grad_fn=<MseLossBackward>)
# tensor(8.2743e-12, grad_fn=<MseLossBackward>)
# tensor(1.0539e-11, grad_fn=<MseLossBackward>)
# tensor(8.7125e-12, grad_fn=<MseLossBackward>)
# tensor(6.1931e-12, grad_fn=<MseLossBackward>)
# tensor(1.4273e-11, grad_fn=<MseLossBackward>)
# tensor(9.0830e-12, grad_fn=<MseLossBackward>)
# tensor(1.3800e-11, grad_fn=<MseLossBackward>)
# tensor(7.4634e-12, grad_fn=<MseLossBackward>)
# tensor(1.2767e-11, grad_fn=<MseLossBackward>)
# tensor(1.3504e-11, grad_fn=<MseLossBackward>)
# tensor(1.2838e-11, grad_fn=<MseLossBackward>)
# tensor(7.9003e-12, grad_fn=<MseLossBackward>)
# tensor(1.1099e-11, grad_fn=<MseLossBackward>)
# tensor(7.7099e-12, grad_fn=<MseLossBackward>)
# tensor(7.0909e-12, grad_fn=<MseLossBackward>)
# tensor(1.0087e-11, grad_fn=<MseLossBackward>)
# tensor(1.1852e-11, grad_fn=<MseLossBackward>)
# tensor(7.4103e-12, grad_fn=<MseLossBackward>)
# tensor(1.0617e-11, grad_fn=<MseLossBackward>)
# tensor(1.2619e-11, grad_fn=<MseLossBackward>)
# tensor(8.9732e-12, grad_fn=<MseLossBackward>)
# tensor(1.1135e-11, grad_fn=<MseLossBackward>)
# tensor(5.2714e-12, grad_fn=<MseLossBackward>)
# tensor(5.7475e-12, grad_fn=<MseLossBackward>)
# tensor(1.2765e-11, grad_fn=<MseLossBackward>)
# tensor(8.7703e-12, grad_fn=<MseLossBackward>)
# tensor(1.1004e-11, grad_fn=<MseLossBackward>)
# tensor(1.3926e-11, grad_fn=<MseLossBackward>)
# tensor(9.8741e-12, grad_fn=<MseLossBackward>)
# tensor(4.6971e-12, grad_fn=<MseLossBackward>)
# tensor(1.1897e-11, grad_fn=<MseLossBackward>)
# tensor(7.1850e-12, grad_fn=<MseLossBackward>)
# tensor(1.1407e-11, grad_fn=<MseLossBackward>)
# tensor(5.5753e-12, grad_fn=<MseLossBackward>)
# tensor(8.5311e-12, grad_fn=<MseLossBackward>)
# tensor(1.2324e-11, grad_fn=<MseLossBackward>)
# tensor(1.0460e-11, grad_fn=<MseLossBackward>)
# tensor(8.6009e-12, grad_fn=<MseLossBackward>)
# tensor(1.0584e-11, grad_fn=<MseLossBackward>)
# tensor(8.4361e-12, grad_fn=<MseLossBackward>)
# tensor(1.1809e-11, grad_fn=<MseLossBackward>)
# tensor(1.0558e-11, grad_fn=<MseLossBackward>)
# tensor(8.7012e-12, grad_fn=<MseLossBackward>)
# tensor(1.4467e-11, grad_fn=<MseLossBackward>)
# tensor(8.5463e-12, grad_fn=<MseLossBackward>)
# tensor(8.0999e-12, grad_fn=<MseLossBackward>)
# tensor(7.2568e-12, grad_fn=<MseLossBackward>)
# tensor(9.6367e-12, grad_fn=<MseLossBackward>)
# tensor(7.7684e-12, grad_fn=<MseLossBackward>)
# tensor(8.8052e-12, grad_fn=<MseLossBackward>)
# tensor(1.0439e-11, grad_fn=<MseLossBackward>)
# tensor(1.1992e-11, grad_fn=<MseLossBackward>)
# tensor(1.1544e-11, grad_fn=<MseLossBackward>)
# tensor(8.4009e-12, grad_fn=<MseLossBackward>)
# tensor(9.7248e-12, grad_fn=<MseLossBackward>)
# tensor(1.1092e-11, grad_fn=<MseLossBackward>)
# tensor(8.7564e-12, grad_fn=<MseLossBackward>)
# tensor(1.1767e-11, grad_fn=<MseLossBackward>)
# tensor(1.3729e-11, grad_fn=<MseLossBackward>)
# tensor(7.2265e-12, grad_fn=<MseLossBackward>)
# tensor(9.8800e-12, grad_fn=<MseLossBackward>)
# tensor(8.8807e-12, grad_fn=<MseLossBackward>)
# tensor(6.9611e-12, grad_fn=<MseLossBackward>)
# tensor(1.1342e-11, grad_fn=<MseLossBackward>)
# tensor(1.0194e-11, grad_fn=<MseLossBackward>)
# tensor(1.1766e-11, grad_fn=<MseLossBackward>)
# tensor(1.5067e-11, grad_fn=<MseLossBackward>)
# tensor(1.2314e-11, grad_fn=<MseLossBackward>)
# tensor(1.1112e-11, grad_fn=<MseLossBackward>)
# tensor(9.1348e-12, grad_fn=<MseLossBackward>)
# tensor(8.7723e-12, grad_fn=<MseLossBackward>)
# tensor(1.3079e-11, grad_fn=<MseLossBackward>)
# tensor(6.5013e-12, grad_fn=<MseLossBackward>)
# tensor(7.9013e-12, grad_fn=<MseLossBackward>)
# tensor(1.2449e-11, grad_fn=<MseLossBackward>)
# tensor(9.3572e-12, grad_fn=<MseLossBackward>)
# tensor(1.3173e-11, grad_fn=<MseLossBackward>)
# tensor(7.2233e-12, grad_fn=<MseLossBackward>)
# tensor(8.7830e-12, grad_fn=<MseLossBackward>)
# tensor(1.1119e-11, grad_fn=<MseLossBackward>)
# tensor(1.0184e-11, grad_fn=<MseLossBackward>)
# ...
# tensor(7.6159e-12, grad_fn=<MseLossBackward>)
# tensor(8.8067e-12, grad_fn=<MseLossBackward>)
# tensor(1.2879e-11, grad_fn=<MseLossBackward>)
# tensor(1.1962e-11, grad_fn=<MseLossBackward>)
# tensor(7.3079e-12, grad_fn=<MseLossBackward>)
# tensor(1.4838e-11, grad_fn=<MseLossBackward>)
# tensor(9.3147e-12, grad_fn=<MseLossBackward>)
# tensor(1.2122e-11, grad_fn=<MseLossBackward>)
# tensor(1.7064e-11, grad_fn=<MseLossBackward>)
# tensor(6.2602e-12, grad_fn=<MseLossBackward>)
# tensor(7.2359e-12, grad_fn=<MseLossBackward>)
# tensor(1.1481e-11, grad_fn=<MseLossBackward>)
# tensor(6.5816e-12, grad_fn=<MseLossBackward>)
# tensor(5.7792e-12, grad_fn=<MseLossBackward>)
# tensor(9.4386e-12, grad_fn=<MseLossBackward>)
# tensor(7.0572e-12, grad_fn=<MseLossBackward>)
# tensor(8.5101e-12, grad_fn=<MseLossBackward>)
# tensor(9.7018e-12, grad_fn=<MseLossBackward>)
# tensor(7.6272e-12, grad_fn=<MseLossBackward>)
# tensor(1.1841e-11, grad_fn=<MseLossBackward>)
# tensor(5.9016e-12, grad_fn=<MseLossBackward>)
# tensor(1.3252e-11, grad_fn=<MseLossBackward>)
# tensor(8.0722e-12, grad_fn=<MseLossBackward>)
# tensor(5.8116e-12, grad_fn=<MseLossBackward>)
# tensor(7.2373e-12, grad_fn=<MseLossBackward>)
# tensor(9.2157e-12, grad_fn=<MseLossBackward>)
# tensor(1.4196e-11, grad_fn=<MseLossBackward>)
# tensor(1.3907e-11, grad_fn=<MseLossBackward>)
# tensor(1.2794e-11, grad_fn=<MseLossBackward>)
# tensor(8.0549e-12, grad_fn=<MseLossBackward>)
# tensor(1.1478e-11, grad_fn=<MseLossBackward>)
# tensor(1.2355e-11, grad_fn=<MseLossBackward>)
# tensor(1.1866e-11, grad_fn=<MseLossBackward>)
# tensor(9.1769e-12, grad_fn=<MseLossBackward>)
# tensor(8.0698e-12, grad_fn=<MseLossBackward>)
# tensor(8.6965e-12, grad_fn=<MseLossBackward>)
# tensor(8.8549e-12, grad_fn=<MseLossBackward>)
# tensor(7.1787e-12, grad_fn=<MseLossBackward>)
# tensor(8.7740e-12, grad_fn=<MseLossBackward>)
# tensor(9.6556e-12, grad_fn=<MseLossBackward>)
# tensor(1.0580e-11, grad_fn=<MseLossBackward>)
# tensor(9.1379e-12, grad_fn=<MseLossBackward>)
# tensor(5.3708e-12, grad_fn=<MseLossBackward>)
# tensor(9.3452e-12, grad_fn=<MseLossBackward>)
# tensor(1.2778e-11, grad_fn=<MseLossBackward>)
# tensor(9.6361e-12, grad_fn=<MseLossBackward>)
# tensor(8.4820e-12, grad_fn=<MseLossBackward>)
# tensor(6.4189e-12, grad_fn=<MseLossBackward>)
# tensor(1.6093e-11, grad_fn=<MseLossBackward>)
# tensor(1.1936e-11, grad_fn=<MseLossBackward>)
# tensor(8.3957e-12, grad_fn=<MseLossBackward>)
# tensor(1.1389e-11, grad_fn=<MseLossBackward>)
# tensor(8.7087e-12, grad_fn=<MseLossBackward>)
# tensor(1.3749e-11, grad_fn=<MseLossBackward>)
# tensor(8.6426e-12, grad_fn=<MseLossBackward>)
# tensor(1.1353e-11, grad_fn=<MseLossBackward>)
# tensor(1.2451e-11, grad_fn=<MseLossBackward>)
# tensor(6.5650e-12, grad_fn=<MseLossBackward>)
# tensor(8.9011e-12, grad_fn=<MseLossBackward>)
# tensor(9.5694e-12, grad_fn=<MseLossBackward>)
# tensor(7.7148e-12, grad_fn=<MseLossBackward>)
# tensor(6.5232e-12, grad_fn=<MseLossBackward>)
# tensor(1.2098e-11, grad_fn=<MseLossBackward>)
# tensor(9.0707e-12, grad_fn=<MseLossBackward>)
# tensor(1.1926e-11, grad_fn=<MseLossBackward>)
# tensor(9.8354e-12, grad_fn=<MseLossBackward>)
# tensor(1.0681e-11, grad_fn=<MseLossBackward>)
# tensor(7.8501e-12, grad_fn=<MseLossBackward>)
# tensor(7.7281e-12, grad_fn=<MseLossBackward>)
# tensor(8.7839e-12, grad_fn=<MseLossBackward>)
# tensor(7.9522e-12, grad_fn=<MseLossBackward>)
# tensor(1.0876e-11, grad_fn=<MseLossBackward>)
# tensor(8.1567e-12, grad_fn=<MseLossBackward>)
# tensor(7.9861e-12, grad_fn=<MseLossBackward>)
# tensor(5.8649e-12, grad_fn=<MseLossBackward>)
# tensor(6.6644e-12, grad_fn=<MseLossBackward>)
# tensor(7.8503e-12, grad_fn=<MseLossBackward>)
# tensor(8.4443e-12, grad_fn=<MseLossBackward>)
# tensor(1.1460e-11, grad_fn=<MseLossBackward>)
# tensor(5.0976e-12, grad_fn=<MseLossBackward>)
# tensor(9.7042e-12, grad_fn=<MseLossBackward>)
# tensor(1.0573e-11, grad_fn=<MseLossBackward>)
# tensor(1.2391e-11, grad_fn=<MseLossBackward>)
# tensor(1.0083e-11, grad_fn=<MseLossBackward>)
# tensor(1.2846e-11, grad_fn=<MseLossBackward>)
# tensor(4.0714e-12, grad_fn=<MseLossBackward>)
# tensor(1.0165e-11, grad_fn=<MseLossBackward>)
# tensor(5.6180e-12, grad_fn=<MseLossBackward>)
# tensor(1.3227e-11, grad_fn=<MseLossBackward>)
# tensor(1.1101e-11, grad_fn=<MseLossBackward>)
# tensor(8.6417e-12, grad_fn=<MseLossBackward>)
# tensor(9.6655e-12, grad_fn=<MseLossBackward>)
# tensor(1.3280e-11, grad_fn=<MseLossBackward>)
# tensor(1.1274e-11, grad_fn=<MseLossBackward>)
# tensor(9.9306e-12, grad_fn=<MseLossBackward>)
# tensor(1.5201e-11, grad_fn=<MseLossBackward>)
# tensor(1.1700e-11, grad_fn=<MseLossBackward>)
# tensor(6.8701e-12, grad_fn=<MseLossBackward>)
# tensor(1.3016e-11, grad_fn=<MseLossBackward>)
# tensor(9.9022e-12, grad_fn=<MseLossBackward>)
# tensor(1.1307e-11, grad_fn=<MseLossBackward>)
# tensor(8.4257e-12, grad_fn=<MseLossBackward>)
# tensor(7.9054e-12, grad_fn=<MseLossBackward>)
# tensor(5.6006e-12, grad_fn=<MseLossBackward>)
# tensor(8.9074e-12, grad_fn=<MseLossBackward>)
# tensor(7.5451e-12, grad_fn=<MseLossBackward>)
# tensor(1.3253e-11, grad_fn=<MseLossBackward>)
# tensor(1.2228e-11, grad_fn=<MseLossBackward>)
# tensor(1.4794e-11, grad_fn=<MseLossBackward>)
# tensor(8.6665e-12, grad_fn=<MseLossBackward>)
# tensor(8.3467e-12, grad_fn=<MseLossBackward>)
# tensor(1.1322e-11, grad_fn=<MseLossBackward>)
# tensor(1.0030e-11, grad_fn=<MseLossBackward>)
# tensor(5.1365e-12, grad_fn=<MseLossBackward>)
# tensor(9.5967e-12, grad_fn=<MseLossBackward>)
# tensor(1.5523e-11, grad_fn=<MseLossBackward>)
# tensor(6.2023e-12, grad_fn=<MseLossBackward>)
# tensor(7.6556e-12, grad_fn=<MseLossBackward>)
# tensor(7.1572e-12, grad_fn=<MseLossBackward>)
# tensor(1.2625e-11, grad_fn=<MseLossBackward>)
# tensor(1.0326e-11, grad_fn=<MseLossBackward>)
# tensor(1.0291e-11, grad_fn=<MseLossBackward>)
# tensor(1.1732e-11, grad_fn=<MseLossBackward>)
# tensor(8.4153e-12, grad_fn=<MseLossBackward>)
# tensor(8.2389e-12, grad_fn=<MseLossBackward>)
# tensor(1.0095e-11, grad_fn=<MseLossBackward>)
# tensor(5.2135e-12, grad_fn=<MseLossBackward>)
# tensor(8.0323e-12, grad_fn=<MseLossBackward>)
# tensor(1.1042e-11, grad_fn=<MseLossBackward>)
# tensor(9.9442e-12, grad_fn=<MseLossBackward>)
# tensor(5.4369e-12, grad_fn=<MseLossBackward>)
# tensor(1.0053e-11, grad_fn=<MseLossBackward>)
# tensor(6.1477e-12, grad_fn=<MseLossBackward>)
# tensor(1.8914e-11, grad_fn=<MseLossBackward>)
# tensor(8.9587e-12, grad_fn=<MseLossBackward>)
# tensor(8.4543e-12, grad_fn=<MseLossBackward>)
# tensor(8.2874e-12, grad_fn=<MseLossBackward>)
# tensor(1.0548e-11, grad_fn=<MseLossBackward>)
# tensor(9.7845e-12, grad_fn=<MseLossBackward>)
# tensor(9.2491e-12, grad_fn=<MseLossBackward>)
# tensor(7.2854e-12, grad_fn=<MseLossBackward>)
# tensor(3.8719e-12, grad_fn=<MseLossBackward>)
# tensor(1.5392e-11, grad_fn=<MseLossBackward>)
# tensor(1.2956e-11, grad_fn=<MseLossBackward>)
# tensor(9.2567e-12, grad_fn=<MseLossBackward>)
# tensor(1.1265e-11, grad_fn=<MseLossBackward>)
# tensor(9.1121e-12, grad_fn=<MseLossBackward>)
# tensor(1.3620e-11, grad_fn=<MseLossBackward>)
# tensor(6.6348e-12, grad_fn=<MseLossBackward>)
# tensor(7.5711e-12, grad_fn=<MseLossBackward>)
# tensor(7.1875e-12, grad_fn=<MseLossBackward>)
# tensor(1.1925e-11, grad_fn=<MseLossBackward>)
# tensor(7.6164e-12, grad_fn=<MseLossBackward>)
# tensor(1.1938e-11, grad_fn=<MseLossBackward>)
# tensor(7.9859e-12, grad_fn=<MseLossBackward>)
# tensor(9.1708e-12, grad_fn=<MseLossBackward>)
# tensor(1.1562e-11, grad_fn=<MseLossBackward>)
# tensor(6.1336e-12, grad_fn=<MseLossBackward>)
# tensor(9.3519e-12, grad_fn=<MseLossBackward>)
# tensor(9.1964e-12, grad_fn=<MseLossBackward>)
# tensor(1.4141e-11, grad_fn=<MseLossBackward>)
# tensor(9.0551e-12, grad_fn=<MseLossBackward>)
# tensor(1.1209e-11, grad_fn=<MseLossBackward>)
# tensor(1.0264e-11, grad_fn=<MseLossBackward>)
# tensor(9.4480e-12, grad_fn=<MseLossBackward>)
# tensor(9.4183e-12, grad_fn=<MseLossBackward>)
# tensor(5.7575e-12, grad_fn=<MseLossBackward>)
# tensor(9.3387e-12, grad_fn=<MseLossBackward>)
# tensor(9.3433e-12, grad_fn=<MseLossBackward>)
# tensor(1.0958e-11, grad_fn=<MseLossBackward>)
# tensor(5.5987e-12, grad_fn=<MseLossBackward>)
# tensor(1.0969e-11, grad_fn=<MseLossBackward>)
# tensor(6.8015e-12, grad_fn=<MseLossBackward>)
# tensor(1.1057e-11, grad_fn=<MseLossBackward>)
# tensor(8.1347e-12, grad_fn=<MseLossBackward>)
# tensor(1.1355e-11, grad_fn=<MseLossBackward>)
# tensor(7.2700e-12, grad_fn=<MseLossBackward>)
# tensor(7.7661e-12, grad_fn=<MseLossBackward>)
# tensor(8.2854e-12, grad_fn=<MseLossBackward>)
# tensor(1.5079e-11, grad_fn=<MseLossBackward>)
# tensor(1.0067e-11, grad_fn=<MseLossBackward>)
# tensor(1.1763e-11, grad_fn=<MseLossBackward>)
# tensor(1.2098e-11, grad_fn=<MseLossBackward>)
# tensor(1.5663e-11, grad_fn=<MseLossBackward>)
# tensor(9.3339e-12, grad_fn=<MseLossBackward>)
# tensor(7.8794e-12, grad_fn=<MseLossBackward>)
# tensor(1.0051e-11, grad_fn=<MseLossBackward>)
# tensor(1.0455e-11, grad_fn=<MseLossBackward>)
# tensor(5.2941e-12, grad_fn=<MseLossBackward>)
# tensor(4.0925e-12, grad_fn=<MseLossBackward>)
# tensor(6.2756e-12, grad_fn=<MseLossBackward>)
# tensor(6.9345e-12, grad_fn=<MseLossBackward>)
# tensor(6.5843e-12, grad_fn=<MseLossBackward>)
# tensor(1.5474e-11, grad_fn=<MseLossBackward>)
# tensor(8.8791e-12, grad_fn=<MseLossBackward>)
# tensor(6.0938e-12, grad_fn=<MseLossBackward>)
# tensor(8.0837e-12, grad_fn=<MseLossBackward>)
# tensor(3.7289e-12, grad_fn=<MseLossBackward>)
# tensor(1.1204e-11, grad_fn=<MseLossBackward>)
# tensor(6.6760e-12, grad_fn=<MseLossBackward>)
# tensor(9.9873e-12, grad_fn=<MseLossBackward>)
# tensor(1.9633e-11, grad_fn=<MseLossBackward>)
# tensor(9.0768e-12, grad_fn=<MseLossBackward>)
# tensor(1.1160e-11, grad_fn=<MseLossBackward>)
# tensor(7.6377e-12, grad_fn=<MseLossBackward>)
# tensor(1.0157e-11, grad_fn=<MseLossBackward>)
# tensor(1.1028e-11, grad_fn=<MseLossBackward>)
# tensor(1.0717e-11, grad_fn=<MseLossBackward>)
# tensor(6.3046e-12, grad_fn=<MseLossBackward>)
# tensor(9.4793e-12, grad_fn=<MseLossBackward>)
# tensor(4.0854e-12, grad_fn=<MseLossBackward>)
# tensor(6.1755e-12, grad_fn=<MseLossBackward>)
# tensor(1.0865e-11, grad_fn=<MseLossBackward>)
# tensor(9.6670e-12, grad_fn=<MseLossBackward>)
# tensor(7.6967e-12, grad_fn=<MseLossBackward>)
# tensor(1.0410e-11, grad_fn=<MseLossBackward>)
# tensor(5.8950e-12, grad_fn=<MseLossBackward>)
# tensor(8.8927e-12, grad_fn=<MseLossBackward>)
# tensor(8.3712e-12, grad_fn=<MseLossBackward>)
# tensor(1.1926e-11, grad_fn=<MseLossBackward>)
# tensor(9.2685e-12, grad_fn=<MseLossBackward>)
# tensor(1.0423e-11, grad_fn=<MseLossBackward>)
# tensor(8.2799e-12, grad_fn=<MseLossBackward>)
# tensor(1.4108e-11, grad_fn=<MseLossBackward>)
# tensor(6.9814e-12, grad_fn=<MseLossBackward>)
# tensor(6.5662e-12, grad_fn=<MseLossBackward>)
# tensor(1.0058e-11, grad_fn=<MseLossBackward>)
# tensor(1.0997e-11, grad_fn=<MseLossBackward>)
# tensor(7.3453e-12, grad_fn=<MseLossBackward>)
# tensor(6.6000e-12, grad_fn=<MseLossBackward>)
# tensor(1.2276e-11, grad_fn=<MseLossBackward>)
# tensor(9.5126e-12, grad_fn=<MseLossBackward>)
# tensor(9.9882e-12, grad_fn=<MseLossBackward>)
# tensor(1.1767e-11, grad_fn=<MseLossBackward>)
# tensor(7.9320e-12, grad_fn=<MseLossBackward>)
# tensor(7.4587e-12, grad_fn=<MseLossBackward>)
# tensor(7.6668e-12, grad_fn=<MseLossBackward>)
# tensor(9.9033e-12, grad_fn=<MseLossBackward>)
# tensor(1.0529e-11, grad_fn=<MseLossBackward>)
# tensor(6.5354e-12, grad_fn=<MseLossBackward>)
# tensor(8.0167e-12, grad_fn=<MseLossBackward>)
# tensor(1.2076e-11, grad_fn=<MseLossBackward>)
# tensor(1.0656e-11, grad_fn=<MseLossBackward>)
# tensor(1.2128e-11, grad_fn=<MseLossBackward>)
# tensor(1.3664e-11, grad_fn=<MseLossBackward>)
# tensor(5.3001e-12, grad_fn=<MseLossBackward>)
# tensor(1.3809e-11, grad_fn=<MseLossBackward>)
# tensor(1.0377e-11, grad_fn=<MseLossBackward>)
# tensor(5.5604e-12, grad_fn=<MseLossBackward>)
# tensor(1.2780e-11, grad_fn=<MseLossBackward>)
# tensor(1.1098e-11, grad_fn=<MseLossBackward>)
# tensor(1.1397e-11, grad_fn=<MseLossBackward>)
# tensor(1.0033e-11, grad_fn=<MseLossBackward>)
# tensor(1.5495e-11, grad_fn=<MseLossBackward>)
# tensor(1.2839e-11, grad_fn=<MseLossBackward>)
# tensor(7.8132e-12, grad_fn=<MseLossBackward>)
# tensor(8.1803e-12, grad_fn=<MseLossBackward>)
# tensor(9.7980e-12, grad_fn=<MseLossBackward>)
# tensor(8.2331e-12, grad_fn=<MseLossBackward>)
# tensor(9.2162e-12, grad_fn=<MseLossBackward>)
# tensor(9.1204e-12, grad_fn=<MseLossBackward>)
# tensor(1.2618e-11, grad_fn=<MseLossBackward>)
# tensor(8.2258e-12, grad_fn=<MseLossBackward>)
# tensor(8.5892e-12, grad_fn=<MseLossBackward>)
# tensor(1.4424e-11, grad_fn=<MseLossBackward>)
# tensor(1.3679e-11, grad_fn=<MseLossBackward>)
# tensor(8.2141e-12, grad_fn=<MseLossBackward>)
# tensor(6.4412e-12, grad_fn=<MseLossBackward>)
# tensor(1.3904e-11, grad_fn=<MseLossBackward>)
# tensor(1.0137e-11, grad_fn=<MseLossBackward>)
# tensor(5.1466e-12, grad_fn=<MseLossBackward>)
# tensor(5.4470e-12, grad_fn=<MseLossBackward>)
# tensor(1.0023e-11, grad_fn=<MseLossBackward>)
# tensor(4.7981e-12, grad_fn=<MseLossBackward>)
# tensor(8.4117e-12, grad_fn=<MseLossBackward>)
# tensor(9.5801e-12, grad_fn=<MseLossBackward>)
# tensor(9.1110e-12, grad_fn=<MseLossBackward>)
# tensor(1.1481e-11, grad_fn=<MseLossBackward>)
# tensor(1.0367e-11, grad_fn=<MseLossBackward>)
# tensor(8.9556e-12, grad_fn=<MseLossBackward>)
# tensor(1.1569e-11, grad_fn=<MseLossBackward>)
# tensor(9.9848e-12, grad_fn=<MseLossBackward>)
# tensor(1.0338e-11, grad_fn=<MseLossBackward>)
# tensor(7.6031e-12, grad_fn=<MseLossBackward>)
# tensor(1.0008e-11, grad_fn=<MseLossBackward>)
# tensor(1.2049e-11, grad_fn=<MseLossBackward>)
# tensor(7.8711e-12, grad_fn=<MseLossBackward>)
# tensor(1.1028e-11, grad_fn=<MseLossBackward>)
# tensor(8.2939e-12, grad_fn=<MseLossBackward>)
# tensor(8.4141e-12, grad_fn=<MseLossBackward>)
# tensor(9.7232e-12, grad_fn=<MseLossBackward>)
# tensor(7.2208e-12, grad_fn=<MseLossBackward>)
# tensor(9.3422e-12, grad_fn=<MseLossBackward>)
# tensor(8.8073e-12, grad_fn=<MseLossBackward>)
# tensor(1.2968e-11, grad_fn=<MseLossBackward>)
# tensor(7.6657e-12, grad_fn=<MseLossBackward>)
# tensor(9.2489e-12, grad_fn=<MseLossBackward>)
# tensor(8.2076e-12, grad_fn=<MseLossBackward>)
# tensor(5.2391e-12, grad_fn=<MseLossBackward>)
# tensor(5.5454e-12, grad_fn=<MseLossBackward>)
# tensor(1.0703e-11, grad_fn=<MseLossBackward>)
# tensor(1.0572e-11, grad_fn=<MseLossBackward>)
# tensor(4.4513e-12, grad_fn=<MseLossBackward>)
# tensor(1.2855e-11, grad_fn=<MseLossBackward>)
# tensor(1.2621e-11, grad_fn=<MseLossBackward>)
# tensor(1.0686e-11, grad_fn=<MseLossBackward>)
# tensor(1.0777e-11, grad_fn=<MseLossBackward>)
# tensor(9.9806e-12, grad_fn=<MseLossBackward>)
# tensor(1.1215e-11, grad_fn=<MseLossBackward>)
# tensor(9.7490e-12, grad_fn=<MseLossBackward>)
# tensor(1.0896e-11, grad_fn=<MseLossBackward>)
# tensor(8.5340e-12, grad_fn=<MseLossBackward>)
# tensor(9.8874e-12, grad_fn=<MseLossBackward>)
# tensor(8.6945e-12, grad_fn=<MseLossBackward>)
# tensor(7.7284e-12, grad_fn=<MseLossBackward>)
# tensor(7.8931e-12, grad_fn=<MseLossBackward>)
# tensor(1.2507e-11, grad_fn=<MseLossBackward>)
# tensor(6.5982e-12, grad_fn=<MseLossBackward>)
# tensor(1.2457e-11, grad_fn=<MseLossBackward>)
# tensor(8.1744e-12, grad_fn=<MseLossBackward>)
# tensor(9.7403e-12, grad_fn=<MseLossBackward>)
# tensor(9.5955e-12, grad_fn=<MseLossBackward>)
# tensor(1.2165e-11, grad_fn=<MseLossBackward>)
# tensor(1.1574e-11, grad_fn=<MseLossBackward>)
# tensor(1.0709e-11, grad_fn=<MseLossBackward>)
# tensor(1.1772e-11, grad_fn=<MseLossBackward>)
# tensor(9.0701e-12, grad_fn=<MseLossBackward>)
# tensor(1.4076e-11, grad_fn=<MseLossBackward>)
# tensor(9.8950e-12, grad_fn=<MseLossBackward>)
# tensor(7.7195e-12, grad_fn=<MseLossBackward>)
# tensor(8.0030e-12, grad_fn=<MseLossBackward>)
# tensor(1.2802e-11, grad_fn=<MseLossBackward>)
# tensor(8.4786e-12, grad_fn=<MseLossBackward>)
# tensor(6.6095e-12, grad_fn=<MseLossBackward>)
# tensor(1.1023e-11, grad_fn=<MseLossBackward>)
# tensor(1.1515e-11, grad_fn=<MseLossBackward>)
# tensor(1.6757e-11, grad_fn=<MseLossBackward>)
# tensor(1.2198e-11, grad_fn=<MseLossBackward>)
# tensor(7.8884e-12, grad_fn=<MseLossBackward>)
# tensor(7.3460e-12, grad_fn=<MseLossBackward>)
# tensor(8.8600e-12, grad_fn=<MseLossBackward>)
# tensor(7.3904e-12, grad_fn=<MseLossBackward>)
# tensor(1.2185e-11, grad_fn=<MseLossBackward>)
# tensor(6.6413e-12, grad_fn=<MseLossBackward>)
# tensor(6.1431e-12, grad_fn=<MseLossBackward>)
# tensor(6.8064e-12, grad_fn=<MseLossBackward>)
# tensor(1.3109e-11, grad_fn=<MseLossBackward>)

# %%
plt.plot(acc_hist_train)

# %%
plt.plot(acc_hist_test)

# %%
plt.plot(acc_hist_train)
plt.plot(acc_hist_test)
